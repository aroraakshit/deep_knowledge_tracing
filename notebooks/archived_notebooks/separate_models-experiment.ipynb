# %% [markdown]
# Making separate models for different Task IDs, repeating them several times and taking the average AUC.<br>
# This model does not take into account second try.

# %%
import json
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import tensorflow as tf
import pprint as pp
import math
import random
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = "../data/student_vectors_n_task_10_n_limit_10000.json"
filepath2 = "../../../student_vectors_n_task_10_n_limit_100000.json"
student_vectors = json.load(open(filepath))
student_vectors2 = json.load(open(filepath2))

# %%
task_ids = []
for i in student_vectors:
    for j in student_vectors[i]:
        if j['task_id'] not in task_ids:
            task_ids.append(j['task_id'])
print("Number of unique task IDs: " + str(len(task_ids)))
print("Number of students: " + str(len(student_vectors)))
# Out:
# Number of unique task IDs: 10
# Number of students: 1255

# %%
split = int(0.8*len(student_vectors))
print(split)
# Out:
# 1004

# %%
import math
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
def calculate_auc (y_true,y_pred,sequence_lengths=[],plot=False):
    if sequence_lengths == []:
        return roc_auc_score(y_true, y_pred)
    else:
        con_y_true = np.zeros([sum(sequence_lengths),2])
        con_y_pred = np.zeros([sum(sequence_lengths),2])
        index = 0
        for i in range(len(y_true)): #per student
            for j in range(sequence_lengths[i]): #up to the sequence length
                con_y_true[index] = y_true[i][j]
                if(plot):
                    con_y_pred[index] = y_pred[0][i][j]
                else:
                    con_y_pred[index] = y_pred[i][j]
                index += 1
        con1_y_true = np.zeros([sum(sequence_lengths)])
        con1_y_pred = np.zeros([sum(sequence_lengths)])
        for i in range(sum(sequence_lengths)):
            if(np.argmax(con_y_true[i]) == 0): #correct
                con1_y_true[i] = 1.
                con1_y_pred[i] = con_y_pred[i][0]
            else:
                con1_y_true[i] = 0.
                con1_y_pred[i] = con_y_pred[i][1]
        fpr, tpr, thresholds = roc_curve(con1_y_true, con1_y_pred)
        #print("tpr: "+str(tpr) + ", fpr: "+str(fpr) + ", thresholds: "+str(thresholds))
        if(plot):
            return [roc_auc_score(con1_y_true, con1_y_pred),fpr,tpr]
        else:
            return roc_auc_score(con1_y_true, con1_y_pred)

def o_calculate_auc(true_all_tasks, predictions_all_tasks, sequence_lengths_all_tasks,plot=False):
    total = 0
    for i in sequence_lengths_all_tasks:
        total += sum(sequence_lengths_all_tasks[i])
    index = 0
    con_y_true = np.zeros([total,2])
    con_y_pred = np.zeros([total,2])
    for i in sequence_lengths_all_tasks: #per task ID
        for j in range(len(true_all_tasks[i])): #per student
            for k in range(sequence_lengths_all_tasks[i][j]): #up to sequence length
                con_y_true[index] = true_all_tasks[i][j][k]
                con_y_pred[index] = predictions_all_tasks[i][0][j][k]
                index += 1
    con1_y_true = np.zeros([total])
    con1_y_pred = np.zeros([total])
    for i in range(total):
        if(np.argmax(con_y_true[i]) == 0): #correct
            con1_y_true[i] = 1.
            con1_y_pred[i] = con_y_pred[i][0]
        else:
            con1_y_true[i] = 0.
            con1_y_pred[i] = con_y_pred[i][1]
    fpr, tpr, thresholds = roc_curve(con1_y_true, con1_y_pred)
    #print("tpr: "+str(tpr) + ", fpr: "+str(fpr) + ", thresholds: "+str(thresholds))
    if(plot == True):
        return [roc_auc_score(con1_y_true, con1_y_pred),fpr,tpr]
    else:
        return roc_auc_score(con1_y_true, con1_y_pred)

# %%
#recorders over task IDs
test_AUC_all_tasks = {} #making AUC plot over epochs over all task IDs
train_AUC_all_tasks = {} #making AUC plot over epochs over all task IDs
true_all_tasks = {}
true_all_tasks['train'] = {}
true_all_tasks['test'] = {}
predictions_all_tasks = {}
predictions_all_tasks['train'] = {}
predictions_all_tasks['test'] = {}
seqlen_all_tasks = {}
seqlen_all_tasks['train'] = {}
seqlen_all_tasks['test'] = {}
np.set_printoptions(threshold=np.nan)

for i in another_2:
    
    print("\n\n\nCalculating for Task ID: "+str(i)+" which has the frequency: " + str(cnt2[another_2[i]]) + "\n")
    
    #recorders over epochs
    train_AUC_taski = [] #making AUC plot over epochs
    test_AUC_taski = [] # making AUC plot over epochs
    
    #configuration variables
    len_vector = 2 #length of input encoding, number of input units and number of output units
    padding_experiment = 1000. #to check if masking is working correctly or not
    num_units = 5 #number of recurrent units
    l_rate = 0.01 #initial learning rate
    epochs = 1000 #when in fixed number of epochs
    display_ep = 20 #status report after 'display_ep' epochs, and convergence criterion
    repeat = 1 #number of times to repeat experiments, recorders work according to 1 right now
    
    #make sequences
    sequences = []
    sequences_lengths = []
    sequences_lengths1 = [] #for passing to mask
    for p in student_vectors:
        interactions = []
        interactions.append([padding_experiment]) #for getting the first prediction!
        for j in student_vectors[p]:
            if(j['task_id'] == i and j['second_try'] == False):
                if(j['correct'] == True):
                    interactions.append([1.,0.])
                else:
                    interactions.append([0.,1.])
        if(len(interactions) > 1):
            sequences_lengths.append(len(interactions)-1)
            sequences_lengths1.append([len(interactions)-1]) 
            sequences.append(interactions)
            
    #add padding
    padded_sequences = np.zeros([len(sequences),max(sequences_lengths)+1,len_vector])
    padded_sequences = padded_sequences + padding_experiment
    for p in range(len(sequences)):
        for j in range(len(sequences[p])):
            padded_sequences[p][j] = sequences[p][j]
    
    split = int(0.8*len(sequences)) #train/test split
    #split the train and test set
    train_x = padded_sequences[:split,:-1]
    train_y = padded_sequences[:split,1:]
    train_seqlen = sequences_lengths[:split]
    test_x = padded_sequences[split:,:-1]
    test_y = padded_sequences[split:,1:]
    test_seqlen = sequences_lengths[split:]
    
    for r in range(repeat): #don't have to repeat results since we fixed the random state
        print("\n\n"+ str(r+1) +" out of "+ str(repeat) + " Time Run.")
        
        # reset graph, fix random seed
        tf.reset_default_graph()
        tf.set_random_seed(1234) #fixing the random states for repeating results
        
        #placeholders
        x = tf.placeholder(tf.float32, [None, max(sequences_lengths), len_vector])
        y = tf.placeholder(tf.float32, [None, max(sequences_lengths), len_vector])
        seqlen_tf = tf.placeholder(tf.float32,[None])
        condition = tf.placeholder(tf.int32, shape=[], name="condition")

        #dynamic RNN definition
        def dynamicRNN(x):
            rnn_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units)
            outputs, states = tf.nn.dynamic_rnn(rnn_cell, x, dtype=tf.float32,sequence_length=seqlen_tf)
            out_size = len_vector
            outputs1 = tf.contrib.layers.fully_connected(outputs, out_size, activation_fn = tf.nn.sigmoid, weights_initializer=tf.contrib.layers.xavier_initializer(uniform=False))
#             out_size = int(len_vector/2)
#             outputs = tf.contrib.layers.fully_connected(outputs, out_size, activation_fn = tf.nn.sigmoid, weights_initializer=tf.contrib.layers.xavier_initializer(uniform=False))
#             opposites = tf.subtract(tf.ones(tf.shape(outputs)),outputs)
#             outputs1 = tf.concat([outputs,opposites],2)
            #outputs = tf.nn.sigmoid(outputs)
            return outputs1
        
        #making predictions and masking cost to feed optimizer
        pred = dynamicRNN(x)
        cost1 = tf.nn.sigmoid_cross_entropy_with_logits(logits=pred, labels=y)
        mask = tf.cond(condition < 1, lambda: tf.cast(tf.sequence_mask(lengths=sequences_lengths1[:split], maxlen = max(sequences_lengths)), tf.float32), lambda: tf.cast(tf.sequence_mask(lengths=sequences_lengths1[split:], maxlen = max(sequences_lengths)), tf.float32))
        cost1 = tf.multiply(cost1,tf.transpose(mask, perm=[0, 2, 1]))
        cost1 = tf.reduce_sum(cost1, 1)
        cost1 /= tf.cond(condition < 1, lambda: tf.cast(sequences_lengths1[:split],tf.float32), lambda: tf.cast(sequences_lengths1[split:],tf.float32) )
        cost = tf.reduce_mean(cost1)
        optimizer = tf.train.AdamOptimizer(learning_rate=l_rate).minimize(cost)

        #execute until cost converges
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            sess.run(tf.local_variables_initializer())
            stop = False
            epoch = 0
            cost_prev = 1.0
            while(stop == False):
                epoch += 1
                loss,_ = sess.run([cost,optimizer], feed_dict={x: train_x, y: train_y, seqlen_tf: train_seqlen,condition:0})
                
                #status report
                if epoch % display_ep == 0 or epoch == 1:
                    
                    loss_train,pred_train = sess.run([cost,pred], feed_dict={x: train_x, y: train_y, seqlen_tf: train_seqlen,condition:0})
                    trainOPTS = calculate_auc(train_y,pred_train,train_seqlen)
                    
                    loss_test,pred_test = sess.run([cost,pred], feed_dict={x: test_x, y: test_y, seqlen_tf: test_seqlen,condition:1})
                    testOPTS = calculate_auc(test_y,pred_test,test_seqlen)
                    
                    print("Epoch: " + str(epoch) +", train cost: "+str(loss_train)+", test cost: "+str(loss_test)+ ", train set AUC: " + str(trainOPTS) + ", test set AUC: "+ str(testOPTS) +";")
                    train_AUC_taski.append(trainOPTS)
                    test_AUC_taski.append(testOPTS)
                    
                    #checking for convergence
                    cost_current = loss_train
                    if abs(cost_prev - cost_current) <= 0.00005:
                        stop = True
                    else:
                        cost_prev = cost_current

            pred_train = sess.run([pred], feed_dict={x: train_x, y: train_y, seqlen_tf: train_seqlen,condition:0})
            predictions_all_tasks['train'][i] = pred_train
            true_all_tasks['train'][i] = train_y
            seqlen_all_tasks['train'][i] = train_seqlen
            pred_test = sess.run([pred], feed_dict={x: test_x, y: test_y, seqlen_tf: test_seqlen,condition:1})
            true_all_tasks['test'][i] = test_y
            predictions_all_tasks['test'][i] = pred_test
            seqlen_all_tasks['test'][i] = test_seqlen
    
    test_AUC_all_tasks[i] = test_AUC_taski
    train_AUC_all_tasks[i] = train_AUC_taski
# Out:
# Calculating for Task ID: p7cfRPp-kQ.partb which has the frequency: 7259
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.73638755, test cost: 0.7348781, train set AUC: 0.1680153097675908, test set AUC: 0.15638210895748586;
# Epoch: 20, train cost: 0.6624211, test cost: 0.665369, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 40, train cost: 0.59145236, test cost: 0.5993533, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.5654902, test cost: 0.57541984, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 80, train cost: 0.55534023, test cost: 0.5661361, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.5499249, test cost: 0.56117225, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 120, train cost: 0.54726887, test cost: 0.5587539, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.5441895, test cost: 0.5560936, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5433689, test cost: 0.5553697, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 180, train cost: 0.5428793, test cost: 0.55493975, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 200, train cost: 0.5425543, test cost: 0.5546542, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 220, train cost: 0.5423194, test cost: 0.55444926, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.5421424, test cost: 0.55429393, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 260, train cost: 0.54200214, test cost: 0.5541722, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.54188883, test cost: 0.55407375, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 300, train cost: 0.54179627, test cost: 0.5539927, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 320, train cost: 0.54171777, test cost: 0.55392474, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 340, train cost: 0.5416506, test cost: 0.55386734, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 360, train cost: 0.54159355, test cost: 0.553818, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 380, train cost: 0.5415443, test cost: 0.5537749, train set AUC: 1.0, test set AUC: 1.0;
#
#
#
# Calculating for Task ID: Ok-iIHxjgx.partb which has the frequency: 2325
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7232465, test cost: 0.7132438, train set AUC: 0.07017496392496393, test set AUC: 0.10218607015760042;
# Epoch: 20, train cost: 0.68653274, test cost: 0.6952145, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 40, train cost: 0.6655641, test cost: 0.68111295, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.6566146, test cost: 0.67692566, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.64803493, test cost: 0.6666315, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.6393086, test cost: 0.6541707, train set AUC: 0.9959235209235209, test set AUC: 0.9983053719708523;
# Epoch: 120, train cost: 0.63547766, test cost: 0.6502507, train set AUC: 0.9874549062049063, test set AUC: 0.9957634299271311;
# Epoch: 140, train cost: 0.63311845, test cost: 0.647676, train set AUC: 0.9767380437023295, test set AUC: 0.9705558379935604;
# Epoch: 160, train cost: 0.6312334, test cost: 0.6452857, train set AUC: 0.9662311894454753, test set AUC: 0.944691577698695;
# Epoch: 180, train cost: 0.6293241, test cost: 0.6427239, train set AUC: 0.9592931869717585, test set AUC: 0.9280630401626843;
# Epoch: 200, train cost: 0.6273183, test cost: 0.6398102, train set AUC: 0.9230223149866008, test set AUC: 0.8970937129300118;
# Epoch: 220, train cost: 0.6257462, test cost: 0.63736135, train set AUC: 0.9087520614306328, test set AUC: 0.8855490594814438;
# Epoch: 240, train cost: 0.6249922, test cost: 0.6366438, train set AUC: 0.9067846835703979, test set AUC: 0.8813548551093034;
# Epoch: 260, train cost: 0.62452614, test cost: 0.6363713, train set AUC: 0.9049899505256648, test set AUC: 0.8813124894085749;
# Epoch: 280, train cost: 0.6241923, test cost: 0.63629985, train set AUC: 0.9032377344877346, test set AUC: 0.8808464667005591;
# Epoch: 300, train cost: 0.6239322, test cost: 0.63631, train set AUC: 0.90161951144094, test set AUC: 0.8766310794780545;
# Epoch: 320, train cost: 0.6237194, test cost: 0.6363368, train set AUC: 0.9008258606472892, test set AUC: 0.8759744111167598;
# Epoch: 340, train cost: 0.6235386, test cost: 0.63637334, train set AUC: 0.9007575757575758, test set AUC: 0.8759744111167598;
# Epoch: 360, train cost: 0.62338066, test cost: 0.63640714, train set AUC: 0.9000489589775303, test set AUC: 0.8759744111167598;
# Epoch: 380, train cost: 0.62324214, test cost: 0.6364322, train set AUC: 0.8985170583384869, test set AUC: 0.8759320454160312;
# Epoch: 400, train cost: 0.6231182, test cost: 0.63644904, train set AUC: 0.8974167697381983, test set AUC: 0.8759320454160311;
# Epoch: 420, train cost: 0.6230056, test cost: 0.6364637, train set AUC: 0.8958101422387137, test set AUC: 0.8759320454160311;
# Epoch: 440, train cost: 0.62290066, test cost: 0.6364742, train set AUC: 0.8950139146567717, test set AUC: 0.8749576342992713;
# Epoch: 460, train cost: 0.62280047, test cost: 0.6364786, train set AUC: 0.8937719027004742, test set AUC: 0.8727546178613794;
# Epoch: 480, train cost: 0.62270373, test cost: 0.6364838, train set AUC: 0.8935412801484229, test set AUC: 0.8733265548212166;
# Epoch: 500, train cost: 0.62261075, test cost: 0.6364956, train set AUC: 0.8942241290455577, test set AUC: 0.8744704287408914;
# Epoch: 520, train cost: 0.6225211, test cost: 0.636517, train set AUC: 0.8942640692640693, test set AUC: 0.8744704287408913;
# Epoch: 540, train cost: 0.6224341, test cost: 0.6365501, train set AUC: 0.8940617913832201, test set AUC: 0.8744704287408913;
# Epoch: 560, train cost: 0.6223481, test cost: 0.63659066, train set AUC: 0.8936391981034839, test set AUC: 0.8744704287408913;
# Epoch: 580, train cost: 0.6222607, test cost: 0.63663554, train set AUC: 0.8935490105132962, test set AUC: 0.8744280630401626;
# Epoch: 600, train cost: 0.62216663, test cost: 0.6366869, train set AUC: 0.8920931251288395, test set AUC: 0.8727334350110151;
# Epoch: 620, train cost: 0.62206364, test cost: 0.6367418, train set AUC: 0.8918496186353329, test set AUC: 0.8714624639891544;
# Epoch: 640, train cost: 0.62196726, test cost: 0.6367828, train set AUC: 0.8916241496598639, test set AUC: 0.8714200982884256;
# Epoch: 660, train cost: 0.6218802, test cost: 0.6368084, train set AUC: 0.8915635951350237, test set AUC: 0.8711659040840536;
# Epoch: 680, train cost: 0.6218011, test cost: 0.63684005, train set AUC: 0.890722273757988, test set AUC: 0.8687298762921538;
# Epoch: 700, train cost: 0.6217344, test cost: 0.63686407, train set AUC: 0.8899440836940837, test set AUC: 0.8683485849855956;
# Epoch: 720, train cost: 0.62167877, test cost: 0.6369291, train set AUC: 0.889013863121006, test set AUC: 0.868179122182681;
# Epoch: 740, train cost: 0.6215996, test cost: 0.637023, train set AUC: 0.8891478561121419, test set AUC: 0.8677978308761227;
# Epoch: 760, train cost: 0.62152344, test cost: 0.6370856, train set AUC: 0.8883761080189652, test set AUC: 0.8678401965768514;
# Epoch: 780, train cost: 0.62146133, test cost: 0.6371387, train set AUC: 0.8870645227788085, test set AUC: 0.8668022369089984;
# Epoch: 800, train cost: 0.6214056, test cost: 0.6372012, train set AUC: 0.8868893011750156, test set AUC: 0.8668446026097272;
# Epoch: 820, train cost: 0.621352, test cost: 0.6372639, train set AUC: 0.8866805813234384, test set AUC: 0.8663997627520758;
# Epoch: 840, train cost: 0.6213019, test cost: 0.63733447, train set AUC: 0.8853277674706246, test set AUC: 0.8630105066937808;
# Epoch: 860, train cost: 0.62125367, test cost: 0.6374062, train set AUC: 0.8846578025149454, test set AUC: 0.8605532960515168;
#
#
#
# Calculating for Task ID: 1zsCldT4p8.set1 which has the frequency: 6346
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7332372, test cost: 0.7325821, train set AUC: 0.14363730789549872, test set AUC: 0.12354596903044691;
# Epoch: 20, train cost: 0.6673391, test cost: 0.6699372, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 40, train cost: 0.607242, test cost: 0.61281484, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.5858688, test cost: 0.5929045, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.57786554, test cost: 0.585419, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.57366586, test cost: 0.5814948, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 120, train cost: 0.57123166, test cost: 0.57918197, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.5689169, test cost: 0.57703793, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5681807, test cost: 0.5763579, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 180, train cost: 0.5677433, test cost: 0.57595545, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 200, train cost: 0.5674601, test cost: 0.57569623, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 220, train cost: 0.5672608, test cost: 0.5755143, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.5671119, test cost: 0.5753787, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 260, train cost: 0.5669963, test cost: 0.5752734, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.5669037, test cost: 0.5751891, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 300, train cost: 0.56682754, test cost: 0.57512015, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 320, train cost: 0.56676316, test cost: 0.57506275, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 340, train cost: 0.56670964, test cost: 0.57501423, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 360, train cost: 0.56666344, test cost: 0.5749726, train set AUC: 1.0, test set AUC: 1.0;
#
#
#
# Calculating for Task ID: DebcfZEEmI.proper_fractions which has the frequency: 6897
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.73369306, test cost: 0.7323151, train set AUC: 0.13829764865205277, test set AUC: 0.10534729119393355;
# Epoch: 20, train cost: 0.6683553, test cost: 0.6721171, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 40, train cost: 0.6101242, test cost: 0.61912733, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.5899839, test cost: 0.601247, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.58210784, test cost: 0.5943098, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.5782894, test cost: 0.5909543, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 120, train cost: 0.5756461, test cost: 0.58862597, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 140, train cost: 0.5741455, test cost: 0.58731675, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5721458, test cost: 0.5856157, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 180, train cost: 0.5715664, test cost: 0.58512056, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 200, train cost: 0.571191, test cost: 0.5848008, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 220, train cost: 0.57094437, test cost: 0.5845904, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.5707704, test cost: 0.5844418, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 260, train cost: 0.5706391, test cost: 0.5843308, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.57053757, test cost: 0.5842441, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 300, train cost: 0.5704551, test cost: 0.5841746, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 320, train cost: 0.5701989, test cost: 0.5839675, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 340, train cost: 0.57016367, test cost: 0.5839366, train set AUC: 1.0, test set AUC: 0.9999999999999999;
#
#
#
# Calculating for Task ID: 9wRCzK1G7F.partb which has the frequency: 6632
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7361846, test cost: 0.73767036, train set AUC: 0.07987045327377333, test set AUC: 0.035742133749197325;
# Epoch: 20, train cost: 0.6686532, test cost: 0.6686308, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 40, train cost: 0.6187606, test cost: 0.61764246, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.5841436, test cost: 0.58063626, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.575549, test cost: 0.5716468, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.57093537, test cost: 0.56682533, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 120, train cost: 0.5684129, test cost: 0.5641541, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.5654319, test cost: 0.5608071, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5645755, test cost: 0.55987144, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 180, train cost: 0.5640744, test cost: 0.5593226, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 200, train cost: 0.563755, test cost: 0.558971, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 220, train cost: 0.5635325, test cost: 0.5587248, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.563366, test cost: 0.55854136, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 260, train cost: 0.5632372, test cost: 0.5583986, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.56313354, test cost: 0.55828387, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 300, train cost: 0.5630494, test cost: 0.55819017, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 320, train cost: 0.56297815, test cost: 0.55811185, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 340, train cost: 0.56291884, test cost: 0.5580456, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 360, train cost: 0.5628668, test cost: 0.5579887, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 380, train cost: 0.56282294, test cost: 0.55793935, train set AUC: 1.0, test set AUC: 1.0;
#
#
#
# Calculating for Task ID: 1zsCldT4p8.set2 which has the frequency: 6443
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7380276, test cost: 0.73578334, train set AUC: 0.10409889187067564, test set AUC: 0.09757610508757299;
# Epoch: 20, train cost: 0.6626985, test cost: 0.66984457, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 40, train cost: 0.60284305, test cost: 0.6179675, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 60, train cost: 0.5608663, test cost: 0.5825059, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 80, train cost: 0.5497924, test cost: 0.57333344, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.54441595, test cost: 0.56887746, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 120, train cost: 0.5399382, test cost: 0.5651282, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.53862524, test cost: 0.56403965, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5379062, test cost: 0.56344175, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 180, train cost: 0.53745353, test cost: 0.5630651, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 200, train cost: 0.5371382, test cost: 0.5628031, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 220, train cost: 0.5369044, test cost: 0.5626085, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.5367236, test cost: 0.56245816, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 260, train cost: 0.5365797, test cost: 0.562338, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.5364618, test cost: 0.56224, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 300, train cost: 0.53636396, test cost: 0.56215847, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 320, train cost: 0.5362808, test cost: 0.5620896, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 340, train cost: 0.53621143, test cost: 0.56203055, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 360, train cost: 0.53614944, test cost: 0.56197995, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 380, train cost: 0.53609556, test cost: 0.56193566, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 400, train cost: 0.5360505, test cost: 0.56189644, train set AUC: 1.0, test set AUC: 1.0;
#
#
#
# Calculating for Task ID: nl-M69Ez9k.parta which has the frequency: 4753
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7333761, test cost: 0.734553, train set AUC: 0.18245420024759001, test set AUC: 0.15214623861240403;
# Epoch: 20, train cost: 0.66529477, test cost: 0.6641196, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 40, train cost: 0.6039379, test cost: 0.59970814, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.5819096, test cost: 0.57657665, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.5735477, test cost: 0.56772316, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 100, train cost: 0.56979644, test cost: 0.56374025, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 120, train cost: 0.5674324, test cost: 0.56123763, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.5656332, test cost: 0.55933064, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5645899, test cost: 0.55821985, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 180, train cost: 0.56307364, test cost: 0.5564882, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 200, train cost: 0.5626321, test cost: 0.5560011, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 220, train cost: 0.56234497, test cost: 0.555684, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.5621506, test cost: 0.5554678, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 260, train cost: 0.56200886, test cost: 0.5553104, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 280, train cost: 0.56190145, test cost: 0.55519, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 300, train cost: 0.56181604, test cost: 0.55509484, train set AUC: 1.0, test set AUC: 0.9999999999999999;
# Epoch: 320, train cost: 0.56174713, test cost: 0.5550173, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 340, train cost: 0.5616898, test cost: 0.5549531, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 360, train cost: 0.56164116, test cost: 0.55489874, train set AUC: 1.0, test set AUC: 1.0;
#
#
#
# Calculating for Task ID: kvig7fcCVc.partb which has the frequency: 3473
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7341945, test cost: 0.73406136, train set AUC: 0.30382648774515686, test set AUC: 0.26773932660792576;
# Epoch: 20, train cost: 0.6547039, test cost: 0.65807277, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 40, train cost: 0.5902031, test cost: 0.5962864, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.557868, test cost: 0.5650046, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.5399109, test cost: 0.5479524, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 100, train cost: 0.53575075, test cost: 0.5439803, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 120, train cost: 0.53356713, test cost: 0.54190725, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.5321609, test cost: 0.54057896, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.5311581, test cost: 0.53963685, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 180, train cost: 0.5303683, test cost: 0.5389008, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 200, train cost: 0.5296301, test cost: 0.5382136, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 220, train cost: 0.5289994, test cost: 0.5376127, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.52854353, test cost: 0.53717744, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 260, train cost: 0.5282213, test cost: 0.53687185, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.5279838, test cost: 0.5366494, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 300, train cost: 0.527801, test cost: 0.5364796, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 320, train cost: 0.52699625, test cost: 0.53581375, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 340, train cost: 0.52684844, test cost: 0.5356831, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 360, train cost: 0.52673215, test cost: 0.5355808, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 380, train cost: 0.5266425, test cost: 0.535502, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 400, train cost: 0.52657145, test cost: 0.5354397, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 420, train cost: 0.52651364, test cost: 0.535389, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 440, train cost: 0.5264656, test cost: 0.5353472, train set AUC: 1.0, test set AUC: 1.0;
#
#
#
# Calculating for Task ID: Ok-iIHxjgx.parta which has the frequency: 1589
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.72870606, test cost: 0.73108023, train set AUC: 0.40019773313089224, test set AUC: 0.43017875920084125;
# Epoch: 20, train cost: 0.6649266, test cost: 0.6588523, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 40, train cost: 0.6154211, test cost: 0.60203654, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 60, train cost: 0.5933376, test cost: 0.57604945, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 80, train cost: 0.5825937, test cost: 0.5631991, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 100, train cost: 0.5776241, test cost: 0.5573657, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 120, train cost: 0.5754133, test cost: 0.55476475, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 140, train cost: 0.5742181, test cost: 0.5533468, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 160, train cost: 0.573387, test cost: 0.55237156, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 180, train cost: 0.57247347, test cost: 0.5513561, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 200, train cost: 0.5734914, test cost: 0.55430806, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 220, train cost: 0.5722866, test cost: 0.55300725, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 240, train cost: 0.57105994, test cost: 0.5517222, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 260, train cost: 0.5702834, test cost: 0.5509442, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 280, train cost: 0.56979936, test cost: 0.5504539, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 300, train cost: 0.5694328, test cost: 0.55007446, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 320, train cost: 0.56913126, test cost: 0.5497555, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 340, train cost: 0.5688709, test cost: 0.549472, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 360, train cost: 0.5686294, test cost: 0.5491972, train set AUC: 0.9999999999999999, test set AUC: 1.0;
# Epoch: 380, train cost: 0.5683572, test cost: 0.5488691, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 400, train cost: 0.5679616, test cost: 0.5483712, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 420, train cost: 0.5676731, test cost: 0.54797924, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 440, train cost: 0.5674386, test cost: 0.5476471, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 460, train cost: 0.56722903, test cost: 0.54735047, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 480, train cost: 0.56703585, test cost: 0.5470817, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 500, train cost: 0.56685376, test cost: 0.546834, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 520, train cost: 0.5666819, test cost: 0.54660296, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 540, train cost: 0.56652, test cost: 0.54638594, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 560, train cost: 0.5663657, test cost: 0.546181, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 580, train cost: 0.5662165, test cost: 0.5459874, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 600, train cost: 0.5660706, test cost: 0.54580665, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 620, train cost: 0.56593186, test cost: 0.54564, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 640, train cost: 0.5658025, test cost: 0.5454826, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 660, train cost: 0.56567866, test cost: 0.54533166, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 680, train cost: 0.56555754, test cost: 0.54518867, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 700, train cost: 0.5654368, test cost: 0.5450557, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 720, train cost: 0.56531554, test cost: 0.5449349, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 740, train cost: 0.565196, test cost: 0.544826, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 760, train cost: 0.565081, test cost: 0.5447204, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 780, train cost: 0.56496775, test cost: 0.54461217, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 800, train cost: 0.5648523, test cost: 0.54450446, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 820, train cost: 0.5647319, test cost: 0.54440194, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 840, train cost: 0.5646033, test cost: 0.54430556, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 860, train cost: 0.5644628, test cost: 0.54421145, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 880, train cost: 0.5643035, test cost: 0.54410684, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 900, train cost: 0.5641119, test cost: 0.543966, train set AUC: 1.0, test set AUC: 1.0;
# Epoch: 920, train cost: 0.56385773, test cost: 0.54374546, train set AUC: 0.9993361816320044, test set AUC: 0.9993690851735015;
# Epoch: 940, train cost: 0.5634842, test cost: 0.5433791, train set AUC: 0.998728858444264, test set AUC: 0.9983175604626708;
# Epoch: 960, train cost: 0.56293035, test cost: 0.54282176, train set AUC: 0.9984181349528619, test set AUC: 0.9983175604626708;
# Epoch: 980, train cost: 0.56225824, test cost: 0.54223675, train set AUC: 0.9982345256170333, test set AUC: 0.9983175604626708;
# Epoch: 1000, train cost: 0.5617607, test cost: 0.541907, train set AUC: 0.9981921542318422, test set AUC: 0.9976866456361725;
# Epoch: 1020, train cost: 0.5614393, test cost: 0.54167926, train set AUC: 0.9981780304367783, test set AUC: 0.9974763406940063;
# Epoch: 1040, train cost: 0.5612057, test cost: 0.54155654, train set AUC: 0.9980014829984817, test set AUC: 0.9968454258675079;
# Epoch: 1060, train cost: 0.561022, test cost: 0.54145324, train set AUC: 0.9979379259206949, test set AUC: 0.9966351209253418;
# Epoch: 1080, train cost: 0.5608698, test cost: 0.54136884, train set AUC: 0.997930864023163, test set AUC: 0.9966351209253418;
# Epoch: 1100, train cost: 0.56073874, test cost: 0.54129785, train set AUC: 0.9979308640231631, test set AUC: 0.9966351209253417;
# Epoch: 1120, train cost: 0.56062317, test cost: 0.54123753, train set AUC: 0.9979308640231631, test set AUC: 0.9966351209253417;
# Epoch: 1140, train cost: 0.56051916, test cost: 0.5411859, train set AUC: 0.9979238021256311, test set AUC: 0.9966351209253418;
# Epoch: 1160, train cost: 0.5604232, test cost: 0.5411426, train set AUC: 0.9979238021256311, test set AUC: 0.9966351209253418;
# Epoch: 1180, train cost: 0.56033045, test cost: 0.5411107, train set AUC: 0.9979167402280993, test set AUC: 0.9966351209253418;
# Epoch: 1200, train cost: 0.5602211, test cost: 0.5410997, train set AUC: 0.9979096783305674, test set AUC: 0.9966351209253418;
# Epoch: 1220, train cost: 0.5599367, test cost: 0.54091704, train set AUC: 0.9763850146534372, test set AUC: 0.9739221871713984;
# Epoch: 1240, train cost: 0.5594459, test cost: 0.5404698, train set AUC: 0.9708061156032626, test set AUC: 0.9665615141955837;
# Epoch: 1260, train cost: 0.5592527, test cost: 0.5406991, train set AUC: 0.9706578157550935, test set AUC: 0.9661409043112513;
# Epoch: 1280, train cost: 0.5591196, test cost: 0.5409388, train set AUC: 0.9709191059637725, test set AUC: 0.9698212407991588;
# Epoch: 1300, train cost: 0.55900556, test cost: 0.5411912, train set AUC: 0.9715546767416405, test set AUC: 0.9739221871713984;
# Epoch: 1320, train cost: 0.5589215, test cost: 0.54123026, train set AUC: 0.9762155291126725, test set AUC: 0.9798107255520504;
# Epoch: 1340, train cost: 0.5588576, test cost: 0.54123014, train set AUC: 0.9762155291126725, test set AUC: 0.9797055730809674;
# Epoch: 1360, train cost: 0.55880237, test cost: 0.5412223, train set AUC: 0.976300271883055, test set AUC: 0.9788643533123028;
# Epoch: 1380, train cost: 0.5587532, test cost: 0.5412157, train set AUC: 0.976300271883055, test set AUC: 0.9788643533123028;
#
#
#
# Calculating for Task ID: hyei4uD81i.parta which has the frequency: 1255
#
#
#
# 1 out of 1 Time Run.
# Epoch: 1, train cost: 0.7183364, test cost: 0.7047886, train set AUC: 0.015789146032091892, test set AUC: 0.0419888704198887;
# Epoch: 20, train cost: 0.6996017, test cost: 0.6901798, train set AUC: 0.8516684045881125, test set AUC: 0.857628098576281;
# Epoch: 40, train cost: 0.6893954, test cost: 0.6850146, train set AUC: 0.9695033694924751, test set AUC: 0.9721037797210378;
# Epoch: 60, train cost: 0.67621976, test cost: 0.6775123, train set AUC: 0.7335338427777691, test set AUC: 0.8132543181325431;
# Epoch: 80, train cost: 0.67025626, test cost: 0.6709363, train set AUC: 0.7267403856629262, test set AUC: 0.8337067283370674;
# Epoch: 100, train cost: 0.6678522, test cost: 0.6673096, train set AUC: 0.6920221623893048, test set AUC: 0.8002457180024571;
# Epoch: 120, train cost: 0.66633826, test cost: 0.6651972, train set AUC: 0.678057833875461, test set AUC: 0.784852207848522;
# Epoch: 140, train cost: 0.6653555, test cost: 0.6637244, train set AUC: 0.6582027298336264, test set AUC: 0.7630989376309895;
# Epoch: 160, train cost: 0.66556156, test cost: 0.66489667, train set AUC: 0.6244260968359454, test set AUC: 0.6740622967406229;
# Epoch: 180, train cost: 0.6645318, test cost: 0.66273177, train set AUC: 0.6415537017726799, test set AUC: 0.7550769675507697;
# Epoch: 200, train cost: 0.66401035, test cost: 0.66286546, train set AUC: 0.6489580253062114, test set AUC: 0.7607140276071402;
# Epoch: 220, train cost: 0.6636122, test cost: 0.6628209, train set AUC: 0.6498957247132429, test set AUC: 0.764905687649057;
# Epoch: 240, train cost: 0.66324973, test cost: 0.6627996, train set AUC: 0.6516466157222232, test set AUC: 0.7664233576642335;
# Epoch: 260, train cost: 0.6628934, test cost: 0.6627442, train set AUC: 0.6552729055452664, test set AUC: 0.7663510876635108;
# Epoch: 280, train cost: 0.6625403, test cost: 0.6627095, train set AUC: 0.6580937855041787, test set AUC: 0.7670737876707379;
# Epoch: 300, train cost: 0.66219014, test cost: 0.66274434, train set AUC: 0.66004311082751, test set AUC: 0.7653393076533931;
# Epoch: 320, train cost: 0.66184103, test cost: 0.66287374, train set AUC: 0.66199632701975, test set AUC: 0.7656283876562838;
# Epoch: 340, train cost: 0.66150457, test cost: 0.6631068, train set AUC: 0.6631830420369478, test set AUC: 0.7642552576425525;
# Epoch: 360, train cost: 0.6611826, test cost: 0.66334563, train set AUC: 0.6660856302429459, test set AUC: 0.7659174676591747;
# Epoch: 380, train cost: 0.66082674, test cost: 0.66336, train set AUC: 0.6672295457021462, test set AUC: 0.7685914576859146;
# Epoch: 400, train cost: 0.66036004, test cost: 0.6629704, train set AUC: 0.672999704293963, test set AUC: 0.7778420177784203;
# Epoch: 420, train cost: 0.6598065, test cost: 0.66259176, train set AUC: 0.676956717974258, test set AUC: 0.7808773578087735;
# Epoch: 440, train cost: 0.66058886, test cost: 0.6642942, train set AUC: 0.6860613512209547, test set AUC: 0.7886825178868252;
# Epoch: 460, train cost: 0.65958905, test cost: 0.66291475, train set AUC: 0.6851119792071965, test set AUC: 0.7886825178868251;
# Epoch: 480, train cost: 0.65919715, test cost: 0.6623858, train set AUC: 0.6837657385647362, test set AUC: 0.7884657078846571;
# Epoch: 500, train cost: 0.658887, test cost: 0.6627415, train set AUC: 0.6843882775901514, test set AUC: 0.7882488978824889;
# Epoch: 520, train cost: 0.65858144, test cost: 0.66312927, train set AUC: 0.6923178684263769, test set AUC: 0.7952590879525909;
# Epoch: 540, train cost: 0.658209, test cost: 0.66356945, train set AUC: 0.6946056993447777, test set AUC: 0.7980776179807763;
# Epoch: 560, train cost: 0.65770316, test cost: 0.66373086, train set AUC: 0.6973409801876955, test set AUC: 0.7993784779937848;
# Epoch: 580, train cost: 0.65706456, test cost: 0.66569626, train set AUC: 0.7017882433505052, test set AUC: 0.7902724579027246;
# Epoch: 600, train cost: 0.65640575, test cost: 0.66686565, train set AUC: 0.707928034488662, test set AUC: 0.7972826479728264;
# Epoch: 620, train cost: 0.6615466, test cost: 0.6676069, train set AUC: 0.7539025415155711, test set AUC: 0.848955698489557;
# Epoch: 640, train cost: 0.66129816, test cost: 0.67634106, train set AUC: 0.6850458344357462, test set AUC: 0.7121485871214859;
# Epoch: 660, train cost: 0.6608668, test cost: 0.6794384, train set AUC: 0.6719491696885749, test set AUC: 0.700079497000795;
# Epoch: 680, train cost: 0.6569003, test cost: 0.671879, train set AUC: 0.7137293200317495, test set AUC: 0.8286478282864782;
# Epoch: 700, train cost: 0.65617764, test cost: 0.671007, train set AUC: 0.6905553048106703, test set AUC: 0.7428633374286334;
# Epoch: 720, train cost: 0.6551937, test cost: 0.67129767, train set AUC: 0.7019750050581296, test set AUC: 0.7570282575702826;
# Epoch: 740, train cost: 0.65460616, test cost: 0.67026645, train set AUC: 0.7004536753147712, test set AUC: 0.7712654477126545;
# Epoch: 760, train cost: 0.65421516, test cost: 0.67189205, train set AUC: 0.7029282679407964, test set AUC: 0.7613644576136446;
# Epoch: 780, train cost: 0.6538322, test cost: 0.67102665, train set AUC: 0.7047919941481331, test set AUC: 0.7747344077473441;
# Epoch: 800, train cost: 0.65332395, test cost: 0.67120254, train set AUC: 0.707251023298523, test set AUC: 0.7736503577365036;
# Epoch: 820, train cost: 0.6529461, test cost: 0.67128557, train set AUC: 0.7113442173906277, test set AUC: 0.7836236178362362;
# Epoch: 840, train cost: 0.6526887, test cost: 0.6737473, train set AUC: 0.7123324980934742, test set AUC: 0.8227216882272169;
# Epoch: 860, train cost: 0.65254796, test cost: 0.6738054, train set AUC: 0.7142234603831727, test set AUC: 0.829659608296596;
# Epoch: 880, train cost: 0.6527554, test cost: 0.6716582, train set AUC: 0.7204527415062333, test set AUC: 0.8110139481101395;
# Epoch: 900, train cost: 0.6523152, test cost: 0.6750434, train set AUC: 0.7164373647923055, test set AUC: 0.8363084483630845;
# Epoch: 920, train cost: 0.66269845, test cost: 0.6856229, train set AUC: 0.730806343672669, test set AUC: 0.8348630483486305;
# Epoch: 940, train cost: 0.6582786, test cost: 0.67628336, train set AUC: 0.7256470514995409, test set AUC: 0.8267688082676881;
# Epoch: 960, train cost: 0.6588788, test cost: 0.6722897, train set AUC: 0.7375297651471526, test set AUC: 0.8358025583580256;
# Epoch: 980, train cost: 0.6574897, test cost: 0.67054737, train set AUC: 0.7354831681011004, test set AUC: 0.835947098359471;
# Epoch: 1000, train cost: 0.65462637, test cost: 0.6752006, train set AUC: 0.7021890028481159, test set AUC: 0.8173737081737371;
# Epoch: 1020, train cost: 0.65322256, test cost: 0.6803107, train set AUC: 0.7041928003361709, test set AUC: 0.7489340174893402;
# Epoch: 1040, train cost: 0.6525145, test cost: 0.6770566, train set AUC: 0.7042783994521657, test set AUC: 0.7607140276071402;
# Epoch: 1060, train cost: 0.65217555, test cost: 0.6755096, train set AUC: 0.7039243303814608, test set AUC: 0.7667847076678471;
# Epoch: 1080, train cost: 0.65199345, test cost: 0.67509127, train set AUC: 0.7047025041632298, test set AUC: 0.7693864276938644;
# Epoch: 1100, train cost: 0.6518573, test cost: 0.6754044, train set AUC: 0.7047725398035889, test set AUC: 0.8057382380573824;
# Epoch: 1120, train cost: 0.6525828, test cost: 0.6753909, train set AUC: 0.7015431186092478, test set AUC: 0.7725663077256631;
# Epoch: 1140, train cost: 0.652057, test cost: 0.674253, train set AUC: 0.7053094797130095, test set AUC: 0.8134711281347113;
# Epoch: 1160, train cost: 0.6522158, test cost: 0.67424214, train set AUC: 0.7029282679407964, test set AUC: 0.8107971381079715;
# Epoch: 1180, train cost: 0.65175647, test cost: 0.6748239, train set AUC: 0.7054378783870013, test set AUC: 0.8110139481101395;
# Epoch: 1200, train cost: 0.65176183, test cost: 0.6754773, train set AUC: 0.7032745552736837, test set AUC: 0.8182409481824094;

# %%
print("Calculating over-all AUC")
o_train = o_calculate_auc(true_all_tasks['train'],predictions_all_tasks['train'],seqlen_all_tasks['train'],plot=False)
o_test = o_calculate_auc(true_all_tasks['test'],predictions_all_tasks['test'],seqlen_all_tasks['test'],plot=False)
print("Overall AUC train: "+str(o_train) + ", test: "+str(o_test))
# Out:
# Calculating over-all AUC
# Overall AUC train: 0.9947154000325478, test: 0.9947189546899559

# %%
fig=plt.figure(figsize=(14, 9), dpi= 80, facecolor='w', edgecolor='k')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Bayesian Knowledge Tracing (separate models, test set)')

for task_id in another_2:
    roc = calculate_auc(true_all_tasks['test'][task_id] , predictions_all_tasks['test'][task_id] , seqlen_all_tasks['test'][task_id],plot=True)
    plt.plot(roc[1], roc[2], label=task_id)

roc = o_calculate_auc(true_all_tasks['test'],predictions_all_tasks['test'],seqlen_all_tasks['test'],plot=True)
plt.plot(roc[1], roc[2], label='overall-test')

plt.legend(loc="lower right")

# %%
fig=plt.figure(figsize=(14, 9), dpi= 80, facecolor='w', edgecolor='k')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Bayesian Knowledge Tracing (separate models, Train set)')

for task_id in another_2:
    roc = calculate_auc(true_all_tasks['train'][task_id],predictions_all_tasks['train'][task_id], seqlen_all_tasks['train'][task_id], plot=True)
    plt.plot(roc[1], roc[2], label=task_id)

roc = o_calculate_auc(true_all_tasks['train'],predictions_all_tasks['train'],seqlen_all_tasks['train'],plot=True)
plt.plot(roc[1], roc[2], label='overall-train')

plt.legend(loc="lower right")

# %%
fig, axs = plt.subplots(5,2, figsize=(20, 30), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=0.1)

axs = axs.ravel()

for i,value in enumerate(another_2):
    axs[i-1].plot(test_AUC_all_tasks[value],label='test')
    axs[i-1].plot(train_AUC_all_tasks[value],label='train')
    axs[i-1].set_ylim(0,1.01)
    axs[i-1].set_xlim(0,20)
    axs[i-1].set_xlabel("Epochs")
    axs[i-1].set_ylabel("AUC")
    axs[i-1].legend(loc="best")
    axs[i-1].set_title("Task ID = "+str(value))

# %%
for i in another_2:
    print(i + " final train acc: " + str(round(train_AUC_all_tasks[i][-1],3)) + "; final test acc: "+str(round(test_AUC_all_tasks[i][-1],3)))
# Out:
# p7cfRPp-kQ.partb final train acc: 1.0; final test acc: 1.0
# Ok-iIHxjgx.partb final train acc: 0.885; final test acc: 0.861
# 1zsCldT4p8.set1 final train acc: 1.0; final test acc: 1.0
# DebcfZEEmI.proper_fractions final train acc: 1.0; final test acc: 1.0
# 9wRCzK1G7F.partb final train acc: 1.0; final test acc: 1.0
# 1zsCldT4p8.set2 final train acc: 1.0; final test acc: 1.0
# nl-M69Ez9k.parta final train acc: 1.0; final test acc: 1.0
# kvig7fcCVc.partb final train acc: 1.0; final test acc: 1.0
# Ok-iIHxjgx.parta final train acc: 0.976; final test acc: 0.979
# hyei4uD81i.parta final train acc: 0.703; final test acc: 0.818

# %% [markdown]
# Visualizing Data

# %%
#frequency distribution of taskids
cnt2 = Counter()
another_2 = {}
seqlen_tasks = {}
temp_seqlen = {}
position_2 = 1
for i in student_vectors:
    for k in temp_seqlen:
        temp_seqlen[k] = 0
    for j in student_vectors[i]:
        if(j['second_try'] == False):
            if j['task_id'] not in another_2:
                another_2[j['task_id']] = str(position_2)
                position_2 = position_2 + 1
            if j['task_id'] not in seqlen_tasks:
                seqlen_tasks[j['task_id']] = []

            if j['task_id'] not in temp_seqlen:
                temp_seqlen[j['task_id']] = 1
            else:
                temp_seqlen[j['task_id']] += 1
            cnt2[another_2[j['task_id']]] += 1
    for k in seqlen_tasks:
        seqlen_tasks[k].append(temp_seqlen[k])
plt.bar(cnt2.keys(), cnt2.values())
plt.title("Task IDs distribution")
plt.xlabel("Frequency of task ID across all students")
plt.ylabel("Task IDs")
plt.show()
print("Task IDs mapping: ")
for i in another_2:
    print("Task ID -> "+str(i)+"("+str(another_2[i])+") is attempted " + str(cnt2[another_2[i]]) + " times." + " Max seq len: "+str(max(seqlen_tasks[i])))
# Out:
# Task IDs mapping:
# Task ID -> p7cfRPp-kQ.partb(1) is attempted 7259 times. Max seq len: 46
# Task ID -> Ok-iIHxjgx.partb(2) is attempted 2325 times. Max seq len: 27
# Task ID -> 1zsCldT4p8.set1(3) is attempted 6346 times. Max seq len: 39
# Task ID -> DebcfZEEmI.proper_fractions(4) is attempted 6897 times. Max seq len: 40
# Task ID -> 9wRCzK1G7F.partb(5) is attempted 6632 times. Max seq len: 43
# Task ID -> 1zsCldT4p8.set2(6) is attempted 6443 times. Max seq len: 28
# Task ID -> nl-M69Ez9k.parta(7) is attempted 4753 times. Max seq len: 56
# Task ID -> kvig7fcCVc.partb(8) is attempted 3473 times. Max seq len: 32
# Task ID -> Ok-iIHxjgx.parta(9) is attempted 1589 times. Max seq len: 39
# Task ID -> hyei4uD81i.parta(10) is attempted 1255 times. Max seq len: 40

# %%
proportion_right_train = {}
proportion_right_test = {}
proportion_wrong_train = {}
proportion_wrong_test = {}
num_of_students_train = {}
num_of_students_test = {}

for k in another_2:
    proportion_right_train[k] = np.zeros((max(seqlen_tasks[k])),dtype=np.float64)
    proportion_right_test[k] = np.zeros((max(seqlen_tasks[k])),dtype=np.float64)
    proportion_wrong_train[k] = np.zeros((max(seqlen_tasks[k])),dtype=np.float64)
    proportion_wrong_test[k] = np.zeros((max(seqlen_tasks[k])),dtype=np.float64)
    num_of_students_train[k] = np.zeros((max(seqlen_tasks[k])),dtype=np.float64)
    num_of_students_test[k] = np.zeros((max(seqlen_tasks[k])),dtype=np.float64)
    for idx,i in enumerate(student_vectors):
        if(idx<split): #training set
            question_number = 0
            right_wrong = []
            did_student_attempt = False
            for j in student_vectors[i]:
                if(j['second_try'] == False and j['task_id'] == k):
                    question_number += 1
                    did_student_attempt = True
                    if(j['correct'] == True):
                        right_wrong.append('right')
                    else:
                        right_wrong.append('wrong')
            if(did_student_attempt):
                for l in range(question_number):
                    num_of_students_train[k][l] += 1
                    if(right_wrong[l] == 'right'):
                        proportion_right_train[k][l] += 1
        else: #test set
            question_number = 0
            right_wrong = []
            did_student_attempt = False
            for j in student_vectors[i]:
                if(j['second_try'] == False and j['task_id'] == k):
                    question_number += 1
                    did_student_attempt = True
                    if(j['correct'] == True):
                        right_wrong.append('right')
                    else:
                        right_wrong.append('wrong')
            if(did_student_attempt):
                for l in range(question_number):
                    num_of_students_test[k][l] += 1
                    if(right_wrong[l] == 'right'):
                        proportion_right_test[k][l] += 1
    for g in range(max(seqlen_tasks[k])):
        proportion_right_train[k][g] = round((proportion_right_train[k][g]) / (num_of_students_train[k][g]),4)
        proportion_right_test[k][g] = round((proportion_right_test[k][g]) / (num_of_students_test[k][g]),4)
        proportion_wrong_train[k][g] = round(1.0 - proportion_right_train[k][g],4)
        proportion_wrong_test[k][g] = round(1.0 - proportion_right_test[k][g],4)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:52: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:51: RuntimeWarning: invalid value encountered in double_scalars

# %%
fig, axs = plt.subplots(10,2, figsize=(20, 70), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=0.10)

axs = axs.ravel()
for i,value in enumerate(another_2):
    N = max(seqlen_tasks[value])
    ind = np.arange(N)
    for k in ['train','test']:
        if(k=='train'):
            axs[2*i].bar(ind,proportion_right_train[value],label="got it right_train")
            axs[2*i].bar(ind,proportion_wrong_train[value],bottom = proportion_right_train[value],label="got it wrong_train")
            axs[2*i].set_ylim(0,1.31)
            axs[2*i].legend(loc="best") 
            axs[2*i].set_xlabel("Attempts on task ID in sequence")
            axs[2*i].set_ylabel("Proportion of Students")
            axs[2*i].set_title("Task ID = "+str(value) + " -> " + str(k))
        else:
            axs[2*i+1].bar(ind,proportion_right_test[value],label="got it right_test")
            axs[2*i+1].bar(ind,proportion_wrong_test[value],bottom = proportion_right_test[value],label="got it wrong_test")
            axs[2*i+1].set_ylim(0,1.31)
            axs[2*i+1].legend(loc="best") 
            axs[2*i+1].set_xlabel("Attempts on task ID in sequence")
            axs[2*i+1].set_ylabel("Proportion of Students")
            axs[2*i+1].set_title("Task ID = "+str(value) + " -> " + str(k))
plt.savefig('proportions_right_wrong.png')

# %%
fig, axs = plt.subplots(10,2, figsize=(20, 70), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=0.1)

axs = axs.ravel()

for i,value in enumerate(another_2):
    N = max(seqlen_tasks[value])
    ind = np.arange(N)
    for k in ['train','test']:
        if k=='train':
            axs[2*i].bar(ind,num_of_students_train[value])
            #axs[2*i].set_ylim(0,2000)
            axs[2*i].set_xlim(0,max(seqlen_tasks[value]))
            axs[2*i].set_xlabel("Attempts on task ID in sequence")
            axs[2*i].set_ylabel("Number of Students")
            axs[2*i].set_title("Task ID = "+str(value) + " -> " + k)
        else:
            axs[2*i+1].bar(ind,num_of_students_test[value])
            #axs[2*i+1].set_ylim(0,1300)
            axs[2*i+1].set_xlim(0,max(seqlen_tasks[value]))
            axs[2*i+1].set_xlabel("Attempts on task ID in sequence")
            axs[2*i+1].set_ylabel("Number of Students")
            axs[2*i+1].set_title("Task ID = "+str(value) + " -> " + k)
plt.savefig('num_students.png')
