# %%
import json
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import tensorflow as tf
import pprint as pp
import math
import random
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = "../data/student_vectors_n_task_10_n_limit_10000.json"
filepath2 = "../../../student_vectors_n_task_10_n_limit_100000.json"
student_vectors2 = json.load(open(filepath))
student_vectors = json.load(open(filepath2))

# %%
baseline = {}
for i in student_vectors:
    for j in student_vectors[i]:
        if j['task_id'] not in baseline:
            baseline[j['task_id']] = 0
baseline
# Out:
# {'1zsCldT4p8.set1': 0,
#  '1zsCldT4p8.set2': 0,
#  '2yCqg9SbT0.set1': 0,
#  '9wRCzK1G7F.partb': 0,
#  'DebcfZEEmI.proper_fractions': 0,
#  'UlJYoQjOUR.partb': 0,
#  'dTZlXODVzW.partb': 0,
#  'kvig7fcCVc.partb': 0,
#  'nl-M69Ez9k.parta': 0,
#  'p7cfRPp-kQ.partb': 0}

# %%
num_right = {}
num_trials = {}
for i in baseline:
    number_of_trials = 0
    number_right = 0
    for j in student_vectors:
        for k in student_vectors[j]:
            if k['task_id'] == i and k['second_try'] == False:
                number_of_trials += 1
                if k['correct'] == True:
                    number_right += 1
    baseline[i] = number_right / number_of_trials
    num_trials[i] = number_of_trials
    num_right[i] = number_right
baseline
# Out:
# {'1zsCldT4p8.set1': 0.8153234455518062,
#  '1zsCldT4p8.set2': 0.885719607269244,
#  '2yCqg9SbT0.set1': 0.7273850020583711,
#  '9wRCzK1G7F.partb': 0.79915882646033,
#  'DebcfZEEmI.proper_fractions': 0.7697333675363282,
#  'UlJYoQjOUR.partb': 0.8975790843037091,
#  'dTZlXODVzW.partb': 0.7910621672873495,
#  'kvig7fcCVc.partb': 0.9113463109175062,
#  'nl-M69Ez9k.parta': 0.8147932327175961,
#  'p7cfRPp-kQ.partb': 0.8725337248784069}

# %%
import math
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
def calculate_auc (y_true,y_pred,sequence_lengths=[],len_vector=1):
    if sequence_lengths == []:
        return roc_auc_score(y_true, y_pred)
    else:
        if(len_vector == 1):
            con_y_true = np.zeros([sum(sequence_lengths)])
            con_y_pred = np.zeros([sum(sequence_lengths)])
        elif(len_vector >= 2):
            con_y_true = np.zeros([sum(sequence_lengths),len_vector])
            con_y_pred = np.zeros([sum(sequence_lengths),len_vector])
        index = 0
        for i in range(len(y_true)): #per student
            for j in range(sequence_lengths[i]): #up to the sequence length
                con_y_true[index] = y_true[i][j]
                con_y_pred[index] = y_pred[i][j]
                index += 1
        fpr, tpr, thresholds = roc_curve(con_y_true, con_y_pred)
        print("tpr: "+str(tpr) + ", fpr: "+str(fpr) + ", thresholds: "+str(thresholds))
        return roc_auc_score(con_y_true, con_y_pred)

# %%
print("with encoding of length 1")
np.set_printoptions(threshold=np.nan)
for i in baseline:
    #build y_true and y_scores
    len_vector = 1
    padding_experiment = 100.0
    sequences = []
    sequences_pred = []
    sequences_lengths = []
    for p in student_vectors:
        interactions = []
        interactions_pred = []
        interactions.append([padding_experiment]) #for getting the first prediction!
        interactions_pred.append([baseline[i]])
        for j in student_vectors[p]:
            if(j['task_id'] == i and j['second_try'] == False):
                if(j['correct'] == True):
                    interactions.append([1.])
                    interactions_pred.append([baseline[i]])
                else:
                    interactions.append([0.])
                    interactions_pred.append([baseline[i]])
        if(len(interactions) > 1):
            sequences_lengths.append(len(interactions)-1)
            sequences.append(interactions)
            sequences_pred.append(interactions_pred)
    
    #add padding
    padded_sequences = np.zeros([len(sequences),max(sequences_lengths)+1,len_vector])
    padded_pred = np.zeros([len(sequences),max(sequences_lengths)+1,len_vector])
    padded_pred = padded_pred + padding_experiment
    padded_sequences = padded_sequences + padding_experiment
    for p in range(len(sequences)):
        for j in range(len(sequences[p])):
            padded_sequences[p][j] = sequences[p][j]
            padded_pred[p][j] = sequences_pred[p][j]

    #split the train and test set like BKT
    split = int(0.8*len(sequences))
    train_x = padded_sequences[:split,:-1]
    train_y = padded_sequences[:split,1:]
    train_pred = padded_pred[:split,1:]
    train_seqlen = sequences_lengths[:split]
    test_x = padded_sequences[split:,:-1]
    test_y = padded_sequences[split:,1:]
    test_pred = padded_pred[split:,1:]
    test_seqlen = sequences_lengths[split:]
    
    print(str(i) + " has %trials correct: " + str(baseline[i]*100))
    update_op_train = calculate_auc(train_y,train_pred,train_seqlen)
    update_op_test = calculate_auc(test_y,test_pred,test_seqlen)
    print("tf auc TRAIN : {}".format(update_op_train))
    print("tf auc TEST : {}".format(update_op_test))
    print("Number of trials who got it right: " + str(num_right[i]) + " out of " + str(num_trials[i]))        
    print("\n\n")
# Out:
# with encoding of length 1
# 1zsCldT4p8.set1 has %trials correct: 81.53234455518063
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.81532345 0.81532345]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.81532345 0.81532345]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 62338 out of 76458
#
#
#
# kvig7fcCVc.partb has %trials correct: 91.13463109175062
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.91134631 0.91134631]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.91134631 0.91134631]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 53558 out of 58768
#
#
#
# p7cfRPp-kQ.partb has %trials correct: 87.25337248784069
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.87253372 0.87253372]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.87253372 0.87253372]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 66556 out of 76279
#
#
#
# dTZlXODVzW.partb has %trials correct: 79.10621672873495
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.79106217 0.79106217]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.79106217 0.79106217]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 34624 out of 43769
#
#
#
# 1zsCldT4p8.set2 has %trials correct: 88.5719607269244
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.88571961 0.88571961]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.88571961 0.88571961]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 66576 out of 75166
#
#
#
# UlJYoQjOUR.partb has %trials correct: 89.75790843037092
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.89757908 0.89757908]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.89757908 0.89757908]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 56578 out of 63034
#
#
#
# 9wRCzK1G7F.partb has %trials correct: 79.915882646033
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.79915883 0.79915883]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.79915883 0.79915883]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 54533 out of 68238
#
#
#
# 2yCqg9SbT0.set1 has %trials correct: 72.73850020583711
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.727385 0.727385]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.727385 0.727385]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 33571 out of 46153
#
#
#
# DebcfZEEmI.proper_fractions has %trials correct: 76.97333675363282
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.76973337 0.76973337]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.76973337 0.76973337]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 51011 out of 66271
#
#
#
# nl-M69Ez9k.parta has %trials correct: 81.47932327175961
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.81479323 0.81479323]
# tpr: [0. 1.], fpr: [0. 1.], thresholds: [1.81479323 0.81479323]
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 41948 out of 51483

# %%
for i in baseline:
    #build y_true and y_scores
    len_vector = 1
    sequences = []
    sequences_pred = []
    sequences_lengths = []
    padding_experiment = 100.0
    for p in student_vectors:
        interactions = []
        interactions_pred = []
        interactions.append([padding_experiment]) #for getting the first prediction!
        interactions_pred.append([baseline[i]])
        for j in student_vectors[p]:
            if(j['task_id'] == i and j['second_try'] == False):
                if(j['correct'] == True):
                    interactions.append([1.])
                    interactions_pred.append([baseline[i]])
                else:
                    interactions.append([0.])
                    interactions_pred.append([1 - baseline[i]])
        if(len(interactions) > 1):
            sequences_lengths.append(len(interactions)-1)
            sequences.append(interactions)
            sequences_pred.append(interactions_pred)
    
    #add padding
    padded_sequences = np.zeros([len(sequences),max(sequences_lengths)+1,len_vector])
    padded_sequences = padded_sequences + padding_experiment
    padded_pred = np.zeros([len(sequences),max(sequences_lengths)+1,len_vector])
    padded_pred = padded_pred + padding_experiment
    for p in range(len(sequences)):
        for j in range(len(sequences[p])):
            padded_sequences[p][j] = sequences[p][j]
            padded_pred[p][j] = sequences_pred[p][j]

    #split the train and test set like BKT
    split = int(0.8*len(sequences))
    train_x = padded_sequences[:split,:-1]
    train_y = padded_sequences[:split,1:]
    train_pred = padded_pred[:split,1:]
    train_seqlen = sequences_lengths[:split]
    test_x = padded_sequences[split:,:-1]
    test_y = padded_sequences[split:,1:]
    test_pred = padded_pred[split:,1:]
    test_seqlen = sequences_lengths[split:]

    print(str(i) + " has %trials correct: " + str(baseline[i]*100))
    update_op_train = calculate_auc(train_y,train_pred,train_seqlen,len_vector=len_vector)
    update_op_test = calculate_auc(test_y,test_pred,test_seqlen,len_vector=len_vector)
    print("tf auc TRAIN : {}".format(update_op_train))
    print("tf auc TEST : {}".format(update_op_test))
    print("Number of trials who got it right: " + str(num_right[i]) + " out of " + str(num_trials[i]))        
    print("\n\n")
# Out:
# 1zsCldT4p8.set1 has %trials correct: 81.53234455518063
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.81532345 0.18467655]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.81532345 0.18467655]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 62338 out of 76458
#
#
#
# kvig7fcCVc.partb has %trials correct: 91.13463109175062
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.91134631 0.08865369]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.91134631 0.08865369]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 53558 out of 58768
#
#
#
# p7cfRPp-kQ.partb has %trials correct: 87.25337248784069
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.87253372 0.12746628]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.87253372 0.12746628]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 66556 out of 76279
#
#
#
# dTZlXODVzW.partb has %trials correct: 79.10621672873495
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.79106217 0.20893783]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.79106217 0.20893783]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 34624 out of 43769
#
#
#
# 1zsCldT4p8.set2 has %trials correct: 88.5719607269244
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.88571961 0.11428039]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.88571961 0.11428039]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 66576 out of 75166
#
#
#
# UlJYoQjOUR.partb has %trials correct: 89.75790843037092
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.89757908 0.10242092]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.89757908 0.10242092]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 56578 out of 63034
#
#
#
# 9wRCzK1G7F.partb has %trials correct: 79.915882646033
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.79915883 0.20084117]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.79915883 0.20084117]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 54533 out of 68238
#
#
#
# 2yCqg9SbT0.set1 has %trials correct: 72.73850020583711
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.727385 0.272615]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.727385 0.272615]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 33571 out of 46153
#
#
#
# DebcfZEEmI.proper_fractions has %trials correct: 76.97333675363282
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.76973337 0.23026663]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.76973337 0.23026663]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 51011 out of 66271
#
#
#
# nl-M69Ez9k.parta has %trials correct: 81.47932327175961
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.81479323 0.18520677]
# tpr: [1. 1.], fpr: [0. 1.], thresholds: [0.81479323 0.18520677]
# tf auc TRAIN : 1.0
# tf auc TEST : 1.0
# Number of trials who got it right: 41948 out of 51483
