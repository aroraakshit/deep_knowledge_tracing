# %%
import json
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import tensorflow as tf
import pprint as pp
import math
import random
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = "../data/student_vectors_n_task_10_n_limit_10000.json"
filepath2 = "../../../student_vectors_n_task_10_n_limit_100000.json"
student_vectors = json.load(open(filepath))
student_vectors2 = json.load(open(filepath2))

# %%
baseline = {}
for i in student_vectors:
    for j in student_vectors[i]:
        if j['task_id'] not in baseline:
            baseline[j['task_id']] = 0
baseline
# Out:
# {'1zsCldT4p8.set1': 0,
#  '1zsCldT4p8.set2': 0,
#  '9wRCzK1G7F.partb': 0,
#  'DebcfZEEmI.proper_fractions': 0,
#  'Ok-iIHxjgx.parta': 0,
#  'Ok-iIHxjgx.partb': 0,
#  'hyei4uD81i.parta': 0,
#  'kvig7fcCVc.partb': 0,
#  'nl-M69Ez9k.parta': 0,
#  'p7cfRPp-kQ.partb': 0}

# %%
num_right = {}
num_trials = {}
for i in baseline:
    number_of_trials = 0
    number_right = 0
    for j in student_vectors:
        for k in student_vectors[j]:
            if k['task_id'] == i:
                number_of_trials += 1
                if k['correct'] == True and k['second_try'] == False:
                    number_right += 1
    baseline[i] = number_right / number_of_trials
    num_trials[i] = number_of_trials
    num_right[i] = number_right
baseline
# Out:
# {'1zsCldT4p8.set1': 0.7511683897464948,
#  '1zsCldT4p8.set2': 0.840260680666184,
#  '9wRCzK1G7F.partb': 0.7289459745762712,
#  'DebcfZEEmI.proper_fractions': 0.7109494640122511,
#  'Ok-iIHxjgx.parta': 0.8574850299401198,
#  'Ok-iIHxjgx.partb': 0.5525277877375403,
#  'hyei4uD81i.parta': 0.41165865384615385,
#  'kvig7fcCVc.partb': 0.9052747859707263,
#  'nl-M69Ez9k.parta': 0.7390815370196814,
#  'p7cfRPp-kQ.partb': 0.8307613168724279}

# %%
print("with encoding of length 1")
import tensorflow as tf
for i in baseline:
    #build y_true and y_scores
    len_vector = 1
    sequences = []
    sequences_pred = []
    sequences_lengths = []
    for p in student_vectors:
        interactions = []
        interactions_pred = []
        interactions.append([0.]) #for getting the first prediction!
        interactions_pred.append([baseline[i]])
        for j in student_vectors[p]:
            if(j['task_id'] == i and j['second_try'] == False):
                if(j['correct'] == True):
                    interactions.append([1.])
                    interactions_pred.append([baseline[i]])
                else:
                    interactions.append([0.])
                    interactions_pred.append([baseline[i]])
        if(len(interactions) > 1):
            sequences_lengths.append(len(interactions))
            sequences.append(interactions)
            sequences_pred.append(interactions_pred)
    
    #add padding
    padded_sequences = np.zeros([len(sequences),max(sequences_lengths),len_vector])
    padded_pred = np.zeros([len(sequences),max(sequences_lengths),len_vector])
    for p in range(len(sequences)):
        for j in range(len(sequences[p])):
            padded_sequences[p][j] = sequences[p][j]
            padded_pred[p][j] = sequences_pred[p][j]

    #split the train and test set like BKT
    split = int(0.8*len(sequences))
    train_x = padded_sequences[:split,:-1]
    train_y = padded_sequences[:split,1:]
    train_pred = padded_pred[:split,1:]
    train_seqlen = sequences_lengths[:split]
    test_x = padded_sequences[split:,:-1]
    test_y = padded_sequences[split:,1:]
    test_pred = padded_pred[split:,1:]
    test_seqlen = sequences_lengths[split:]
    
    train_pred = np.ones_like(train_y) * baseline[i]
    test_pred = np.ones_like(test_y) * baseline[i]
    
    tf.reset_default_graph()
    auc_train, update_op_train = tf.metrics.auc(labels = train_y, predictions=train_pred, curve='ROC')
    auc_test, update_op_test = tf.metrics.auc(labels = test_y, predictions=test_pred, curve='ROC')
    with tf.Session() as sess:
        sess.run(tf.local_variables_initializer())
        sess.run(tf.global_variables_initializer())
        print(str(i) + " has %trials correct: " + str(baseline[i]*100))
        update_op_train = sess.run([auc_train, update_op_train])
        update_op_test = sess.run([auc_test,update_op_test])
        print("tf auc TRAIN : {}".format(update_op_train[1]))
        print("tf auc TEST : {}".format(update_op_test[1]))
        print("Number of trials who got it right: " + str(num_right[i]) + " out of " + str(num_trials[i]))        
        print("\n\n")
# Out:
# with encoding of length 1
# p7cfRPp-kQ.partb has %trials correct: 83.07613168724279
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 6460 out of 7776
#
#
#
# Ok-iIHxjgx.partb has %trials correct: 55.25277877375403
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 1541 out of 2789
#
#
#
# 1zsCldT4p8.set1 has %trials correct: 75.11683897464948
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 5304 out of 7061
#
#
#
# DebcfZEEmI.proper_fractions has %trials correct: 71.09494640122512
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 5571 out of 7836
#
#
#
# 9wRCzK1G7F.partb has %trials correct: 72.89459745762711
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 5505 out of 7552
#
#
#
# 1zsCldT4p8.set2 has %trials correct: 84.0260680666184
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 5802 out of 6905
#
#
#
# nl-M69Ez9k.parta has %trials correct: 73.90815370196813
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 3943 out of 5335
#
#
#
# kvig7fcCVc.partb has %trials correct: 90.52747859707263
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 3278 out of 3621
#
#
#
# Ok-iIHxjgx.parta has %trials correct: 85.74850299401197
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 1432 out of 1670
#
#
#
# hyei4uD81i.parta has %trials correct: 41.16586538461539
# tf auc TRAIN : 0.5
# tf auc TEST : 0.5
# Number of trials who got it right: 685 out of 1664

# %%
print("With constrained encoding of ")

import tensorflow as tf
for i in baseline:
    #build y_true and y_scores
    len_vector = 1
    sequences = []
    sequences_pred = []
    sequences_lengths = []
    for p in student_vectors:
        interactions = []
        interactions_pred = []
        interactions.append([0.]) #for getting the first prediction!
        interactions_pred.append([baseline[i]])
        for j in student_vectors[p]:
            if(j['task_id'] == i and j['second_try'] == False):
                if(j['correct'] == True):
                    interactions.append([1.])
                    interactions_pred.append([baseline[i]])
                else:
                    interactions.append([0.])
                    interactions_pred.append([baseline[i]])
        if(len(interactions) > 1):
            sequences_lengths.append(len(interactions))
            sequences.append(interactions)
            sequences_pred.append(interactions_pred)
    
    #add padding
    padded_sequences = np.zeros([len(sequences),max(sequences_lengths),len_vector])
    padded_pred = np.zeros([len(sequences),max(sequences_lengths),len_vector])
    for p in range(len(sequences)):
        for j in range(len(sequences[p])):
            padded_sequences[p][j] = sequences[p][j]
            padded_pred[p][j] = sequences_pred[p][j]

    #split the train and test set like BKT
    split = int(0.8*len(sequences))
    train_x = padded_sequences[:split,:-1]
    train_y = padded_sequences[:split,1:]
    train_pred = padded_pred[:split,1:]
    train_seqlen = sequences_lengths[:split]
    test_x = padded_sequences[split:,:-1]
    test_y = padded_sequences[split:,1:]
    test_pred = padded_pred[split:,1:]
    test_seqlen = sequences_lengths[split:]
    
#     train_pred = np.ones_like(train_y) * baseline[i]
#     test_pred = np.ones_like(test_y) * baseline[i]
    
    tf.reset_default_graph()
    auc_train, update_op_train = tf.metrics.auc(labels = train_y, predictions=train_pred, curve='ROC')
    auc_test, update_op_test = tf.metrics.auc(labels = test_y, predictions=test_pred, curve='ROC')
    with tf.Session() as sess:
        sess.run(tf.local_variables_initializer())
        sess.run(tf.global_variables_initializer())
        print(str(i) + " has %trials correct: " + str(baseline[i]*100))
        update_op_train = sess.run([auc_train, update_op_train])
        update_op_test = sess.run([auc_test,update_op_test])
        print("tf auc TRAIN : {}".format(update_op_train[1]))
        print("tf auc TEST : {}".format(update_op_test[1]))
        print("Number of trials who got it right: " + str(num_right[i]) + " out of " + str(num_trials[i]))        
        print("\n\n")
