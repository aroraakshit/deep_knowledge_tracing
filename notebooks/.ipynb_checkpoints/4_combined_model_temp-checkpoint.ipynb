# %%
import json
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import tensorflow as tf
import pprint as pp
import math
import random
import matplotlib.pyplot as plt
import os
from collections import Counter
# %matplotlib inline
np.set_printoptions(threshold=np.nan)
import pickle
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f)
        
def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
'''
Loading data from file
'''
filepath = "../data/student_vectors_n_task_10_n_limit_10000.json"
student_vectors = json.load(open(filepath))
#filepath2 = "../../../student_vectors_n_task_10_n_limit_100000.json"

# %%
'''
Generate one hot encoding from task IDs
'''
#Collect task IDs
task_ids = []
for i in student_vectors:
    for j in student_vectors[i]:
        if j['task_id'] not in task_ids:
            task_ids.append(j['task_id'])

#pre-processing for using MultiLabelBinarizer
temp_ids = [[x] for x in task_ids]

#generating encodings
enc = MultiLabelBinarizer()
task_ids_1hot = (enc.fit_transform(temp_ids)).astype(float)
task_ids_dict = dict(zip(task_ids, task_ids_1hot))

# %%
'''
Split train and test student_vectors
'''
split = int(0.8*len(student_vectors))
split2 = int(0.6*len(student_vectors))
train_student_vectors = {}
test_student_vectors = {}
valid_student_vectors = {}

for idx,keys in enumerate(student_vectors):
    if(idx < split2):
        train_student_vectors[keys] = student_vectors[keys]
    elif (idx < split):
        valid_student_vectors[keys] = student_vectors[keys]
    else:
        test_student_vectors[keys] = student_vectors[keys]
length_interaction_vector = 20

# %%
'''
Gather Training Data from train_student_vectors
train_X, train_Y, train_Seqlen
'''
train_sequences = {}
train_sequences['overall'] = []
incorrect_vec = np.zeros((len(task_ids)), dtype=np.float)
temp_seqlen = {}
temp_seqlen['overall'] = []

for i in task_ids: #go per task IDs
    train_sequences[i] = []
    temp_seqlen[i] = []
    for j in train_student_vectors: #go per student
        temp = [] #one student sequence
        temp.append(np.concatenate([incorrect_vec,incorrect_vec])) #for getting first output
        for k in train_student_vectors[j]: #per question
            if(k['second_try'] == False and k['task_id'] == i):
                if(k['correct'] == True):
                    temp.append(np.concatenate([task_ids_dict[k['task_id']],incorrect_vec]))
                else:
                    temp.append(np.concatenate([incorrect_vec,task_ids_dict[k['task_id']]]))
        if(len(temp) > 1):
            train_sequences['overall'].append(temp)
            train_sequences[i].append(temp)
            random.shuffle(train_sequences['overall'])
            temp_seqlen['overall'].append(len(temp)-1)
            temp_seqlen[i].append(len(temp)-1)

print("Maximum sequence length is: "+ str(max(temp_seqlen['overall'])))
# Out:
# Maximum sequence length is: 41

# %%
'''continued
Gather Training Data
train_X, train_Y, train_Seqlen, train_mask
'''
train_X = {}
train_Y = {}
train_Seqlen = {}
train_mask = {}

for i in task_ids:
    train_X[i] = np.zeros(shape=(len(train_sequences[i]),max(temp_seqlen[i]),len(train_sequences[i][0][0])),dtype=float)
    train_Y[i] = np.zeros(shape=(len(train_sequences[i]),max(temp_seqlen[i]),len(train_sequences[i][0][0])),dtype=float)
    train_Seqlen[i] = np.zeros(shape=(len(train_sequences[i])),dtype=int)
    train_mask[i] = np.zeros(shape=(len(train_sequences[i]),1),dtype=int)
    for idx, seq in enumerate(train_sequences[i]):
        vec1 = np.concatenate([task_ids_dict[i],incorrect_vec])
        vec2 = np.concatenate([incorrect_vec,task_ids_dict[i]])
        if(train_sequences[i][idx][1].all() == vec1.all() or train_sequences[i][idx][1].all() == vec2.all()):
            leng = len(train_sequences[i][idx])
            train_Seqlen[i][idx] = leng-1
            train_mask[i][idx] = [leng-1]
            for pos in range(leng-1):
                train_X[i][idx][pos] = train_sequences[i][idx][pos]
                train_Y[i][idx][pos] = train_sequences[i][idx][pos+1]

train_X['overall'] = np.zeros(shape =(len(train_sequences['overall']), max(temp_seqlen['overall']), len(train_sequences['overall'][0][0])),dtype=float)
train_Y['overall'] = np.zeros(shape =(len(train_sequences['overall']), max(temp_seqlen['overall']), len(train_sequences['overall'][0][0])),dtype=float)
train_Seqlen['overall'] = np.zeros(shape=(len(train_sequences['overall'])),dtype=int)
train_mask['overall'] = np.zeros(shape=(len(train_sequences['overall']),1),dtype=int)

for idx, seq in enumerate(train_sequences['overall']):
    leng = len(seq)
    train_Seqlen['overall'][idx] = leng-1
    train_mask['overall'][idx] = [leng-1]
    for pos in range(leng-1):
        train_X['overall'][idx][pos] = train_sequences['overall'][idx][pos]
        train_Y['overall'][idx][pos] = train_sequences['overall'][idx][pos+1]

# %%
'''
Gathering test data for evaluation metric 1 from test_student_vectors
1) Input one skill at a time and get predictions for each separately
a- calculate 10 separate AUCs
b- concatenate separate predictions to calculate 1 AUC

test_1_X, test_1_Y, test_1_Seqlen
'''
test_sequences = {}
incorrect_vec = np.zeros((len(task_ids)), dtype=np.float)
temp_seqlen = {}
temp_seqlen['overall'] = []
test_sequences['overall'] = []

for i in task_ids: #go per task IDs
    temp_seqlen[i] = []
    test_sequences[i] = []
    for j in test_student_vectors: #go per student
        temp = [] #one student sequence
        temp.append(np.concatenate([incorrect_vec,incorrect_vec])) #for getting first output
        for k in test_student_vectors[j]: #per question
            if(k['second_try'] == False and k['task_id'] == i):
                if(k['correct'] == True):
                    temp.append(np.concatenate([task_ids_dict[k['task_id']],incorrect_vec]))
                else:
                    temp.append(np.concatenate([incorrect_vec,task_ids_dict[k['task_id']]]))
        if(len(temp) > 1):
            test_sequences[i].append(temp)
            test_sequences['overall'].append(temp)
            random.shuffle(test_sequences['overall'])
            temp_seqlen['overall'].append(len(temp)-1)
            temp_seqlen[i].append(len(temp)-1)

print("Maximum sequence length is: "+ str(max(temp_seqlen['overall'])))
# Out:
# Maximum sequence length is: 39

# %%
'''continued
Gathering test data for evaluation metric 1
test_1_X, test_1_Y, test_1_Seqlen
'''
test_1_X = {}
test_1_Y = {}
test_1_Seqlen = {}
test_1_mask = {}

for i in task_ids:
    test_1_X[i] = np.zeros(shape=(len(test_sequences[i]),max(temp_seqlen[i]),len(test_sequences[i][0][0])),dtype=float)
    test_1_Y[i] = np.zeros(shape=(len(test_sequences[i]),max(temp_seqlen[i]),len(test_sequences[i][0][0])),dtype=float)
    test_1_Seqlen[i] = np.zeros(shape=(len(test_sequences[i])),dtype=int)
    test_1_mask[i] = np.zeros(shape=(len(test_sequences[i]),1),dtype=int)

    for idx, seq in enumerate(test_sequences[i]): #go per student
        vec1 = np.concatenate([task_ids_dict[i],incorrect_vec])
        vec2 = np.concatenate([incorrect_vec,task_ids_dict[i]])
        if(test_sequences[i][idx][1].all() == vec1.all() or test_sequences[i][idx][1].all() == vec2.all()):
            leng = len(test_sequences[i][idx])
            test_1_Seqlen[i][idx] = leng-1
            test_1_mask[i][idx] = [leng-1]
            for pos in range(leng-1):
                test_1_X[i][idx][pos] = test_sequences[i][idx][pos]
                test_1_Y[i][idx][pos] = test_sequences[i][idx][pos+1]

test_1_X['overall'] = np.zeros(shape=(len(test_sequences['overall']),max(temp_seqlen['overall']),len(test_sequences['overall'][0][0])),dtype=float)
test_1_Y['overall'] = np.zeros(shape=(len(test_sequences['overall']),max(temp_seqlen['overall']),len(test_sequences['overall'][0][0])),dtype=float)
test_1_Seqlen['overall'] = np.zeros(shape=(len(test_sequences['overall'])),dtype=int)
test_1_mask['overall'] = np.zeros(shape=(len(test_sequences['overall']),1),dtype=int)
for idx, seq in enumerate(test_sequences['overall']):
    leng = len(seq)
    test_1_Seqlen['overall'][idx] = leng-1
    test_1_mask['overall'][idx] = [leng-1]
    for pos in range(leng-1):
        test_1_X['overall'][idx][pos] = test_sequences['overall'][idx][pos]
        test_1_Y['overall'][idx][pos] = test_sequences['overall'][idx][pos+1]

# %%
'''
Gathering test data for evaluation metric 2 from test_student_vectors
2) Input the natural sequence of students and get predictions for the same
a- calculate 1 AUC with natural sequence predictions
b- filter predictions per skill, and calculate 10 separate AUCs

test_2_X, test_2_Y, test_2_Seqlen
'''
test_sequences_2 = {}
incorrect_vec = np.zeros((len(task_ids)), dtype=np.float)
temp_seqlen = {}
temp_seqlen['overall'] = []
test_sequences_2['overall'] = []

#first lets get a natural sequence in overall!, rest part will be done after getting predictions from the model
for j in test_student_vectors: #go per student
    temp = [] #one student sequence
    temp.append(np.concatenate([incorrect_vec,incorrect_vec])) #for getting first output
    for k in test_student_vectors[j]: #per question
        if(k['second_try'] == False):
            if(k['correct'] == True):
                temp.append(np.concatenate([task_ids_dict[k['task_id']],incorrect_vec]))
            else:
                temp.append(np.concatenate([incorrect_vec,task_ids_dict[k['task_id']]]))
    if(len(temp) > 1):
        test_sequences_2['overall'].append(temp)
        random.shuffle(test_sequences_2['overall'])
        temp_seqlen['overall'].append(len(temp)-1)

print("Maximum sequence length is: "+ str(max(temp_seqlen['overall'])))
# Out:
# Maximum sequence length is: 85

# %%
'''continued
Gathering test data for evaluation metric 2
test_2_X, test_2_Y, test_2_Seqlen
'''
test_2_X = {}
test_2_Y = {}
test_2_Seqlen = {}
test_2_mask = {}

test_2_X['overall'] = np.zeros(shape=(len(test_sequences_2['overall']),max(temp_seqlen['overall']),len(test_sequences_2['overall'][0][0])),dtype=float)
test_2_Y['overall'] = np.zeros(shape=(len(test_sequences_2['overall']),max(temp_seqlen['overall']),len(test_sequences_2['overall'][0][0])),dtype=float)
test_2_Seqlen['overall'] = np.zeros(shape=(len(test_sequences_2['overall'])),dtype=int)
test_2_mask['overall'] = np.zeros(shape=(len(test_sequences_2['overall']),1),dtype=int)
for idx, seq in enumerate(test_sequences_2['overall']):
    leng = len(seq)
    test_2_Seqlen['overall'][idx] = leng-1
    test_2_mask['overall'][idx] = [leng-1]
    for pos in range(leng-1):
        test_2_X['overall'][idx][pos] = test_sequences_2['overall'][idx][pos]
        test_2_Y['overall'][idx][pos] = test_sequences_2['overall'][idx][pos+1]

# %%
'''
let's define AUC functions
'''
import math
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

def calculate_auc (y_true, y_pred, sequence_lengths=[], plot=False, debug=False, idx = 0, _2b = False):
    if sequence_lengths == []:
        con1_y_true = np.zeros([len(y_true)])
        con1_y_pred = np.zeros([len(y_true)])
        index_two = idx
        right = 0
        index_one = index_two + int(length_interaction_vector/2)
        for i in range(len(y_true)): #go up to sequence length
            if(np.argmax(y_true[i]) == index_one):
                print("incorrect true label")
                con1_y_true[i] = 0.
                con1_y_pred[i] = 1.0 - y_pred[i][index_one]
            elif (np.argmax(y_true[i]) == index_two):
                print("correct true label")
                right += 1
                con1_y_true[i] = 1.
                con1_y_pred[i] = y_pred[i][index_two]
        return [roc_auc_score(con1_y_true, con1_y_pred),con1_y_pred,con1_y_true, (right/len(y_true))]
    
    elif (_2b):
        incorrect_vec = np.zeros((len(task_ids)), dtype=np.float)
        # For evaluation algorithm 2b
        auc = {}
        for k in task_ids:
            #first determine the sequence lengths for this task ID
            true = []
            pred = []
            print("Starting "+str(k))
            for i in range(len(y_true)): #per student sequence
                vec1 = np.concatenate([task_ids_dict[k],incorrect_vec])
                vec2 = np.concatenate([incorrect_vec,task_ids_dict[k]])
                temp = 0
                for j in range(sequence_lengths[i]): #up to natural sequence length
                    if(np.argmax(y_true[i][j]) == np.argmax(vec1)): #correct
                        true.append(1.)
                        pred.append(y_pred[i][j][np.argmax(vec1)])
                    elif (np.argmax(y_true[i][j]) == np.argmax(vec2)): #incorrect
                        true.append(0.)
                        pred.append(1.0 - y_pred[i][j][np.argmax(vec2)])
            auc[k] = roc_auc_score(true, pred)
            print(str(k) + ": "+str(auc[k]))
        return auc
    else:
        con_y_true = np.zeros([sum(sequence_lengths), length_interaction_vector])
        con_y_pred = np.zeros([sum(sequence_lengths), length_interaction_vector], dtype=np.float)
        index = 0
        for i in range(len(y_true)): #per sequence
            for j in range(sequence_lengths[i]): #up to the sequence length
                con_y_true[index] = y_true[i][j]
                con_y_pred[index] = y_pred[i][j]
                index += 1
        con1_y_true = np.zeros([sum(sequence_lengths)])
        con1_y_pred = np.zeros([sum(sequence_lengths)])
        right = 0
        for l in range(sum(sequence_lengths)): # go per interaction vector
            index_one = np.argmax(con_y_true[l]) #detect its indices!, index_two => correct
            if(index_one >= int(length_interaction_vector/2)):
                index_two = index_one - int(length_interaction_vector/2)
            else:
                index_two = index_one
                index_one = index_one + int(length_interaction_vector/2)
            if(np.argmax(con_y_true[l]) == index_one): #true is incorrect
                con1_y_true[l] = 0.
                con1_y_pred[l] = 1.0 - con_y_pred[l][index_one]
            elif(np.argmax(con_y_true[l]) == index_two):
                right += 1
                con1_y_true[l] = 1.
                con1_y_pred[l] = con_y_pred[l][index_two]
        if(debug):
            print(np.c_[con1_y_true,con1_y_pred])
        fpr, tpr, thresholds = roc_curve(con1_y_true, con1_y_pred)
        #print("tpr: "+str(tpr) + ", fpr: "+str(fpr) + ", thresholds: "+str(thresholds))
        if(plot):
            return [roc_auc_score(con1_y_true, con1_y_pred),fpr,tpr]
        else:
            return [roc_auc_score(con1_y_true, con1_y_pred)]

# %%
'''
load and save model functions
'''
def loadmodel(session, saver, checkpoint_dir):
    session.run(tf.global_variables_initializer())
    ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
    if ckpt and ckpt.model_checkpoint_path:
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        saver.restore(session, os.path.join(checkpoint_dir, ckpt_name))
        print("Model restored successfully")
        return int(ckpt_name[6:])
    else:
        print("No pre-trained model exists, starting from the beginning!")
        return 0

def save(session, saver, checkpoint_dir, step):
    dir1 = os.path.join(checkpoint_dir, "model")
    saver.save(session, dir1, global_step=step)

# %%
'''
Build the model
'''
num_units = 50
lr = 0.001
tf.reset_default_graph()
tf.set_random_seed(1234)

#defining placeholders
x = tf.placeholder(tf.float32, [None, None, length_interaction_vector])
y = tf.placeholder(tf.float32, [None, None, length_interaction_vector])
seqlen_tf = tf.placeholder(tf.float32,[None])

#variables
converged = tf.Variable(0,trainable=False)

#dynamic RNN definition
def dynamicRNN(x):
    rnn_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units)
    outputs, states = tf.nn.dynamic_rnn(rnn_cell, x, dtype=tf.float32,sequence_length=seqlen_tf)
    out_size = int(length_interaction_vector / 2)
    outputs = tf.contrib.layers.fully_connected(outputs, out_size, activation_fn = tf.nn.sigmoid, weights_initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    opposites = tf.subtract(tf.ones(tf.shape(outputs)),outputs)
    outputs1 = tf.concat([outputs,opposites],2)
    return outputs1

#making predictions
pred = dynamicRNN(x)
pred = pred*y
# Define loss and optimizer
cost1 = tf.nn.sigmoid_cross_entropy_with_logits(logits=pred, labels=y)
mask = tf.cast(tf.sequence_mask(lengths = train_mask['overall'], maxlen = max(train_Seqlen['overall'])), tf.float32)
cost1 = tf.multiply(cost1,tf.transpose(mask, perm=[0, 2, 1]))
cost1 = tf.reduce_sum(cost1, 1)
cost1 /= tf.cast(train_mask['overall'],tf.float32)
cost = tf.reduce_mean(cost1)
optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(cost)

saver = tf.train.Saver(max_to_keep=5)
saver_url = 'saved_models/4_combined_model_D_small/model.ckpt'

# %%
'''
All the recorders
'''
predictions = {}
for i in ['train','test1','test2']:
    predictions[i] = {}
    for j in task_ids:
        predictions[i][j] = []
    predictions[i]['overall'] = []

# %%
'''
Training the model
'''
display_step = 20
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    cost_prev = 1.0
    stop = False
    step = loadmodel(sess, saver,saver_url)
    print("converged = "+str(converged.eval()))
    if(sess.run(converged) == 1):
        print("Model has already converged! Stop training")
        stop = True
        
    
    while(stop == False):
        # train on train_X['overall']
        sess.run(optimizer, feed_dict={x: train_X['overall'], y: train_Y['overall'], seqlen_tf: train_Seqlen['overall']})
        step += 1
        if step % display_step == 0 or step == 1:
            # first lets check convergence
            loss = sess.run(cost, feed_dict={x: train_X['overall'], y: train_Y['overall'], seqlen_tf: train_Seqlen['overall']})
            cost_current = loss
            if cost_prev - cost_current <= 0.00005:
                stop = True
                sess.run(converged.assign(1))
                print("Model has converged!")
            else:
                cost_prev = cost_current
                
            # save the model
            save(sess, saver, saver_url, step)

            # report the AUC scores till now
            # train AUC
            predict = sess.run(pred, feed_dict={x: train_X['overall'], y: train_Y['overall'], seqlen_tf: train_Seqlen['overall']})
            predictions['train']['overall'].append(predict)
            print("Training AUC (similar to 1b): "+str(calculate_auc(train_Y['overall'], predict, train_Seqlen['overall'])))
            print("Training AUC (similar to 1a): ")
            for i in task_ids:
                predict = sess.run(pred, feed_dict={x: train_X[i], y: train_Y[i], seqlen_tf: train_Seqlen[i]})
                predictions['train'][i].append(predict)
                print(str(i)+": "+str(calculate_auc(train_Y[i], predict, sequence_lengths= train_Seqlen[i])))
            
            # test AUC 1
            predict = sess.run(pred, feed_dict={x: test_1_X['overall'], y: test_1_Y['overall'], seqlen_tf: test_1_Seqlen['overall']})
            predictions['test1']['overall'].append(predict)
            print("Test AUC 1b: "+str(calculate_auc(test_1_Y['overall'], predict, test_1_Seqlen['overall'])))
            print("Test AUC 1a: ")
            for i in task_ids:
                predict = sess.run(pred, feed_dict={x: test_1_X[i], y: test_1_Y[i], seqlen_tf: test_1_Seqlen[i]})
                predictions['test1'][i].append(predict)
                print(str(i)+": "+str(calculate_auc(test_1_Y[i], predict, test_1_Seqlen[i])))
            
            # test AUC 2
            predict = sess.run(pred, feed_dict={x: test_2_X['overall'], y: test_2_Y['overall'], seqlen_tf: test_2_Seqlen['overall']})
            predictions['test2']['overall'].append(predict)
            print("Test AUC 2a: "+str(calculate_auc(test_2_Y['overall'], predict, test_2_Seqlen['overall'])))
            print("Test AUC 2b: ")
            ans = calculate_auc(test_2_Y['overall'], predict, test_2_Seqlen['overall'], _2b = True)
            print("\n\n\n")
# Out:
# No pre-trained model exists, starting from the beginning!
# converged = 0
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   # Remove the CWD from sys.path while we load stuff.
# Training AUC (similar to 1b): [0.5363008315211485]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.43243772654184726]
# Ok-iIHxjgx.partb: [0.6667625485401985]
# 1zsCldT4p8.set1: [0.5376688325353723]
# DebcfZEEmI.proper_fractions: [0.4570050144101821]
# 9wRCzK1G7F.partb: [0.5030719588556929]
# 1zsCldT4p8.set2: [0.4475953131505383]
# nl-M69Ez9k.parta: [0.6760313220555668]
# kvig7fcCVc.partb: [0.3520250254233541]
# Ok-iIHxjgx.parta: [0.3394649506232799]
# hyei4uD81i.parta: [0.3616071428571428]
# Test AUC 1b: [0.5153827090837395]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.5244842012264838]
# Ok-iIHxjgx.partb: [0.7012265561293829]
# 1zsCldT4p8.set1: [0.41488749114103474]
# DebcfZEEmI.proper_fractions: [0.4175699357434932]
# 9wRCzK1G7F.partb: [0.5130967334454593]
# 1zsCldT4p8.set2: [0.4895735594851438]
# nl-M69Ez9k.parta: [0.6350866352083488]
# kvig7fcCVc.partb: [0.32762276785714284]
# Ok-iIHxjgx.parta: [0.3223026973026973]
# hyei4uD81i.parta: [0.45347981089669076]
# Test AUC 2a: [0.49718349290910024]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.5244842012264838
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6122145963577059
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.39834337349397586
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.37989475313418974
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.4511223237032779
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5387315048718875
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.6096827952962325
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4568638392857143
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.3535214785214785
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.49099046733317836
#
#
#
#
# Training AUC (similar to 1b): [0.580461597694554]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5380136084085066]
# Ok-iIHxjgx.partb: [0.6144814588427059]
# 1zsCldT4p8.set1: [0.5694829347787126]
# DebcfZEEmI.proper_fractions: [0.5796669831908973]
# 9wRCzK1G7F.partb: [0.4018407063511206]
# 1zsCldT4p8.set2: [0.49116794543904513]
# nl-M69Ez9k.parta: [0.6164568636851356]
# kvig7fcCVc.partb: [0.5545109873104302]
# Ok-iIHxjgx.parta: [0.6711793751011818]
# hyei4uD81i.parta: [0.6294718844984802]
# Test AUC 1b: [0.5829379170257966]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6227912898867061]
# Ok-iIHxjgx.partb: [0.6743306605055721]
# 1zsCldT4p8.set1: [0.4673768603827073]
# DebcfZEEmI.proper_fractions: [0.5944725424507342]
# 9wRCzK1G7F.partb: [0.3894956462498137]
# 1zsCldT4p8.set2: [0.5229670395765669]
# nl-M69Ez9k.parta: [0.5614966419494171]
# kvig7fcCVc.partb: [0.6389508928571429]
# Ok-iIHxjgx.parta: [0.6573738761238761]
# hyei4uD81i.parta: [0.6345423544912036]
# Test AUC 2a: [0.5759041501129214]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6227912898867061
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6873301168795869
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.46327958894401133
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.49945329545511274
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.37525991214437276
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5888788644292072
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.5607226674656081
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.6207589285714286
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.5241008991008991
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5863365108889407
#
#
#
#
# Training AUC (similar to 1b): [0.5669837876214437]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5369087201010184]
# Ok-iIHxjgx.partb: [0.5981860348051202]
# 1zsCldT4p8.set1: [0.5746766900642948]
# DebcfZEEmI.proper_fractions: [0.5473105435887183]
# 9wRCzK1G7F.partb: [0.41927974672245255]
# 1zsCldT4p8.set2: [0.4955367870100517]
# nl-M69Ez9k.parta: [0.5859484510193366]
# kvig7fcCVc.partb: [0.5589877083609675]
# Ok-iIHxjgx.parta: [0.6476040148939615]
# hyei4uD81i.parta: [0.5947454407294832]
# Test AUC 1b: [0.5890559026928118]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6226483733499636]
# Ok-iIHxjgx.partb: [0.651613889643925]
# 1zsCldT4p8.set1: [0.47503986534372783]
# DebcfZEEmI.proper_fractions: [0.5610062359267265]
# 9wRCzK1G7F.partb: [0.40099919808676276]
# 1zsCldT4p8.set2: [0.5239173583543848]
# nl-M69Ez9k.parta: [0.5248701720220706]
# kvig7fcCVc.partb: [0.6466517857142857]
# Ok-iIHxjgx.parta: [0.6550949050949051]
# hyei4uD81i.parta: [0.6164264124622181]
# Test AUC 2a: [0.5785819408444864]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6226483733499636
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6657277792878501
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4605776045357902
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.4960207897509124
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.42225699545109396
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5876368338746542
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.49435747634384436
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.6837053571428572
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6905594405594405
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5582810199178485
#
#
#
#
# Training AUC (similar to 1b): [0.54600472056845]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5358166067097266]
# Ok-iIHxjgx.partb: [0.5696282180353806]
# 1zsCldT4p8.set1: [0.5749616634496258]
# DebcfZEEmI.proper_fractions: [0.5308487847135456]
# 9wRCzK1G7F.partb: [0.4251596753884342]
# 1zsCldT4p8.set2: [0.4876968219036856]
# nl-M69Ez9k.parta: [0.5699093669383376]
# kvig7fcCVc.partb: [0.5699197506300571]
# Ok-iIHxjgx.parta: [0.6272057633155254]
# hyei4uD81i.parta: [0.5577697568389057]
# Test AUC 1b: [0.5701532659909568]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6230446419291134]
# Ok-iIHxjgx.partb: [0.6102507474857298]
# 1zsCldT4p8.set1: [0.4751727498228207]
# DebcfZEEmI.proper_fractions: [0.545154300492783]
# 9wRCzK1G7F.partb: [0.4076344978816717]
# 1zsCldT4p8.set2: [0.5181432695777698]
# nl-M69Ez9k.parta: [0.5090723541307768]
# kvig7fcCVc.partb: [0.6552455357142857]
# Ok-iIHxjgx.parta: [0.6254995004995005]
# hyei4uD81i.parta: [0.592749748120592]
# Test AUC 2a: [0.5776344029040037]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6230446419291134
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6472784724109812
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.44888377037562016
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.4987368379008542
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.46087656923066006
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5473535426440514
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.471194417396949
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.5838169642857144
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6033966033966034
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5071301247771836
#
#
#
#
# Training AUC (similar to 1b): [0.542808977693882]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5363809741185877]
# Ok-iIHxjgx.partb: [0.5660955702574428]
# 1zsCldT4p8.set1: [0.5755342718646097]
# DebcfZEEmI.proper_fractions: [0.5270118446698985]
# 9wRCzK1G7F.partb: [0.42090831223636704]
# 1zsCldT4p8.set2: [0.49500981383453274]
# nl-M69Ez9k.parta: [0.5608679770791956]
# kvig7fcCVc.partb: [0.574111840650838]
# Ok-iIHxjgx.parta: [0.6225109276347741]
# hyei4uD81i.parta: [0.6080813069908815]
# Test AUC 1b: [0.5732662013693955]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6222456085645982]
# Ok-iIHxjgx.partb: [0.6237258765969014]
# 1zsCldT4p8.set1: [0.467642629340893]
# DebcfZEEmI.proper_fractions: [0.543169688103809]
# 9wRCzK1G7F.partb: [0.4093625144592763]
# 1zsCldT4p8.set2: [0.5180470347648263]
# nl-M69Ez9k.parta: [0.4999407035677727]
# kvig7fcCVc.partb: [0.6574776785714286]
# Ok-iIHxjgx.parta: [0.6254995004995005]
# hyei4uD81i.parta: [0.6094416027280478]
# Test AUC 2a: [0.5755842452505233]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6222456085645982
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6124592280511009
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.43005846917080087
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.48267021483741157
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.4814353537288965
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.46067003488511965
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.4601871270566499
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4641741071428571
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.5861482267732269
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5243741765480896
#
#
#
#
# Training AUC (similar to 1b): [0.5432155920526277]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5356451389456662]
# Ok-iIHxjgx.partb: [0.5756567908336929]
# 1zsCldT4p8.set1: [0.5739599979700527]
# DebcfZEEmI.proper_fractions: [0.5283885584820163]
# 9wRCzK1G7F.partb: [0.42919813802258905]
# 1zsCldT4p8.set2: [0.5000745454905925]
# nl-M69Ez9k.parta: [0.5578814236467821]
# kvig7fcCVc.partb: [0.5740510456736083]
# Ok-iIHxjgx.parta: [0.625182127246236]
# hyei4uD81i.parta: [0.6432256838905775]
# Test AUC 1b: [0.5794422452879299]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6296220507223782]
# Ok-iIHxjgx.partb: [0.6389406088611036]
# 1zsCldT4p8.set1: [0.47422041105598867]
# DebcfZEEmI.proper_fractions: [0.543601559730592]
# 9wRCzK1G7F.partb: [0.4143833429137127]
# 1zsCldT4p8.set2: [0.5192680139540479]
# nl-M69Ez9k.parta: [0.49702581579407284]
# kvig7fcCVc.partb: [0.6558035714285715]
# Ok-iIHxjgx.parta: [0.6200049950049951]
# hyei4uD81i.parta: [0.6366930171277997]
# Test AUC 2a: [0.58232343472616]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6296220507223782
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6212591736885023
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4206458185683912
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.4939438117538981
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.5261189528290504
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.46328942619992786
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.506163708086785
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4528459821428572
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6305101148851149
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5340230954041696
#
#
#
#
# Training AUC (similar to 1b): [0.5480197606929342]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5402378632618392]
# Ok-iIHxjgx.partb: [0.5868539958770795]
# 1zsCldT4p8.set1: [0.5736714757256264]
# DebcfZEEmI.proper_fractions: [0.5299768437536441]
# 9wRCzK1G7F.partb: [0.4259953241652533]
# 1zsCldT4p8.set2: [0.5041043636868296]
# nl-M69Ez9k.parta: [0.5570828482067439]
# kvig7fcCVc.partb: [0.5676067780872796]
# Ok-iIHxjgx.parta: [0.6246559818682208]
# hyei4uD81i.parta: [0.6513297872340427]
# Test AUC 1b: [0.585002784068504]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6247921214011019]
# Ok-iIHxjgx.partb: [0.6504111171513998]
# 1zsCldT4p8.set1: [0.4736667257264352]
# DebcfZEEmI.proper_fractions: [0.5447823416928369]
# 9wRCzK1G7F.partb: [0.4158487861304493]
# 1zsCldT4p8.set2: [0.5218543245519067]
# nl-M69Ez9k.parta: [0.4966856415249794]
# kvig7fcCVc.partb: [0.6467633928571428]
# Ok-iIHxjgx.parta: [0.6207074175824177]
# hyei4uD81i.parta: [0.6109044408277146]
# Test AUC 2a: [0.5825089581154526]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6247921214011019
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.640935036694754
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4415086817859674
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5136501390476855
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.5122664338989306
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5010104655359076
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.5572116945047811
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4756138392857142
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6507867132867132
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5153452685421995
#
#
#
#
# Training AUC (similar to 1b): [0.5517509993799522]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5376022561069778]
# Ok-iIHxjgx.partb: [0.5779534613356345]
# 1zsCldT4p8.set1: [0.5775926101397293]
# DebcfZEEmI.proper_fractions: [0.5292108551151982]
# 9wRCzK1G7F.partb: [0.4289757414958493]
# 1zsCldT4p8.set2: [0.5014108130613216]
# nl-M69Ez9k.parta: [0.5566650686026072]
# kvig7fcCVc.partb: [0.5666464937878587]
# Ok-iIHxjgx.parta: [0.6079002752145054]
# hyei4uD81i.parta: [0.6753723404255318]
# Test AUC 1b: [0.5891615959862656]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6227685531649516]
# Ok-iIHxjgx.partb: [0.6469998640935037]
# 1zsCldT4p8.set1: [0.46130846917080087]
# DebcfZEEmI.proper_fractions: [0.5441557533788338]
# 9wRCzK1G7F.partb: [0.41573524089331715]
# 1zsCldT4p8.set2: [0.5212949597016721]
# nl-M69Ez9k.parta: [0.49697900282126184]
# kvig7fcCVc.partb: [0.6515625]
# Ok-iIHxjgx.parta: [0.6025693056943058]
# hyei4uD81i.parta: [0.6317523056653492]
# Test AUC 2a: [0.5838221851099679]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6227685531649516
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6279695569448219
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.47798547129695246
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.512876265034375
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.46836700659272035
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5555906411644412
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.5408926921828576
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4224888392857143
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6469624125874127
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.47839649693869646
#
#
#
#
# Training AUC (similar to 1b): [0.5540594181094718]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5371639345379228]
# Ok-iIHxjgx.partb: [0.5820059686466273]
# 1zsCldT4p8.set1: [0.5764720578804723]
# DebcfZEEmI.proper_fractions: [0.5307508287937094]
# 9wRCzK1G7F.partb: [0.4278428676427298]
# 1zsCldT4p8.set2: [0.5037371874938044]
# nl-M69Ez9k.parta: [0.557736684701961]
# kvig7fcCVc.partb: [0.5623148516602555]
# Ok-iIHxjgx.parta: [0.6100959203496843]
# hyei4uD81i.parta: [0.6771808510638297]
# Test AUC 1b: [0.5934255654250254]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6227133354121193]
# Ok-iIHxjgx.partb: [0.6487190812720848]
# 1zsCldT4p8.set1: [0.46217221828490435]
# DebcfZEEmI.proper_fractions: [0.5446650124069479]
# 9wRCzK1G7F.partb: [0.4156891131407322]
# 1zsCldT4p8.set2: [0.5216438108985926]
# nl-M69Ez9k.parta: [0.5037544004194442]
# kvig7fcCVc.partb: [0.6407366071428571]
# Ok-iIHxjgx.parta: [0.6050355894105894]
# hyei4uD81i.parta: [0.6310547934588854]
# Test AUC 2a: [0.5879697945127549]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6227133354121193
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6412680076107639
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4774760807937633
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5408131169148889
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.5056382306813424
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5016239624684229
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.5864105060794448
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4147879464285714
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6421078921078922
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.4932283189955824
#
#
#
#
# Training AUC (similar to 1b): [0.5563767375038772]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5369192239210022]
# Ok-iIHxjgx.partb: [0.5873154273934512]
# 1zsCldT4p8.set1: [0.5735653648386848]
# DebcfZEEmI.proper_fractions: [0.529579689139887]
# 9wRCzK1G7F.partb: [0.4274996818837042]
# 1zsCldT4p8.set2: [0.5036733480045203]
# nl-M69Ez9k.parta: [0.557355432276328]
# kvig7fcCVc.partb: [0.5597490272803644]
# Ok-iIHxjgx.parta: [0.6076574388861907]
# hyei4uD81i.parta: [0.6774012158054712]
# Test AUC 1b: [0.5955993891025051]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6234961282610956]
# Ok-iIHxjgx.partb: [0.651240146779016]
# 1zsCldT4p8.set1: [0.4638997165131113]
# DebcfZEEmI.proper_fractions: [0.5444528211452336]
# 9wRCzK1G7F.partb: [0.4153520257179962]
# 1zsCldT4p8.set2: [0.5215295320582221]
# nl-M69Ez9k.parta: [0.4983740294110304]
# kvig7fcCVc.partb: [0.6402343749999999]
# Ok-iIHxjgx.parta: [0.5984172077922079]
# hyei4uD81i.parta: [0.62840037200651]
# Test AUC 2a: [0.5895324479385033]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6234961282610956
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6451991030171242
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.48467399007795886
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5314542340894
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.5103964857749108
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5014224708288222
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.588748033855142
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4522879464285714
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6323208041958043
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.4941098969231962
#
#
#
#
# Training AUC (similar to 1b): [0.5585454575165572]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5364110661434062]
# Ok-iIHxjgx.partb: [0.5913754254758138]
# 1zsCldT4p8.set1: [0.571800162324815]
# DebcfZEEmI.proper_fractions: [0.5300513102437237]
# 9wRCzK1G7F.partb: [0.4385669003317905]
# 1zsCldT4p8.set2: [0.5042578163722516]
# nl-M69Ez9k.parta: [0.5569650480560693]
# kvig7fcCVc.partb: [0.5588205221735862]
# Ok-iIHxjgx.parta: [0.6071717662295613]
# hyei4uD81i.parta: [0.6811550151975685]
# Test AUC 1b: [0.5966056184801363]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6232135432907182]
# Ok-iIHxjgx.partb: [0.6560818157107909]
# 1zsCldT4p8.set1: [0.46177356484762583]
# DebcfZEEmI.proper_fractions: [0.5444428356740941]
# 9wRCzK1G7F.partb: [0.41704810769765743]
# 1zsCldT4p8.set2: [0.5224046673884277]
# nl-M69Ez9k.parta: [0.49741280303597735]
# kvig7fcCVc.partb: [0.6375558035714286]
# Ok-iIHxjgx.parta: [0.5996659590409591]
# hyei4uD81i.parta: [0.6255618848329846]
# Test AUC 2a: [0.591884537723836]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6232135432907182
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6511348192443599
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4708318568391212
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5525011108836643
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.5190046340649905
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5020058943822927
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.607242278980351
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.4154575892857143
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.6288086913086913
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.5086510888940556
#
#
#
#
# Training AUC (similar to 1b): [0.5621039198693306]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.536120365828178]
# Ok-iIHxjgx.partb: [0.6005710964092238]
# 1zsCldT4p8.set1: [0.5684427641779584]
# DebcfZEEmI.proper_fractions: [0.5271506155563329]
# 9wRCzK1G7F.partb: [0.45196690830843794]
# 1zsCldT4p8.set2: [0.5049560855687067]
# nl-M69Ez9k.parta: [0.5671241695774262]
# kvig7fcCVc.partb: [0.5560142812928328]
# Ok-iIHxjgx.parta: [0.6123118018455561]
# hyei4uD81i.parta: [0.6832218844984802]
# Test AUC 1b: [0.5982480045885501]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6227750493711672]
# Ok-iIHxjgx.partb: [0.6627446316933949]
# 1zsCldT4p8.set1: [0.4614413536498937]
# DebcfZEEmI.proper_fractions: [0.5435291650648306]
# 9wRCzK1G7F.partb: [0.4223492509562638]
# 1zsCldT4p8.set2: [0.5227986286539156]
# nl-M69Ez9k.parta: [0.5107139290440167]
# kvig7fcCVc.partb: [0.6364397321428572]
# Ok-iIHxjgx.parta: [0.6046297452547452]
# hyei4uD81i.parta: [0.625]
# Test AUC 2a: [0.5908627222384144]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6227750493711672
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6695603424843707
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4526709780297661
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5150506013749994
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.4757368021403278
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5285877541200529
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.49444486055975834
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.41540178571428577
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.47274600399600397
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.4570351856157483
#
#
#
#
# Training AUC (similar to 1b): [0.5634944575325072]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5354600446043296]
# Ok-iIHxjgx.partb: [0.6017890958339326]
# 1zsCldT4p8.set1: [0.5688008440606471]
# DebcfZEEmI.proper_fractions: [0.5269602012427741]
# 9wRCzK1G7F.partb: [0.4564431369495401]
# 1zsCldT4p8.set2: [0.5049326909732548]
# nl-M69Ez9k.parta: [0.5675474282583384]
# kvig7fcCVc.partb: [0.5549020095503383]
# Ok-iIHxjgx.parta: [0.6090335114133074]
# hyei4uD81i.parta: [0.6838031914893618]
# Test AUC 1b: [0.5974062573546945]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6232460243217961]
# Ok-iIHxjgx.partb: [0.6631931231312856]
# 1zsCldT4p8.set1: [0.4625044294826364]
# DebcfZEEmI.proper_fractions: [0.5436090488339467]
# 9wRCzK1G7F.partb: [0.42363727973998144]
# 1zsCldT4p8.set2: [0.5228166726813425]
# nl-M69Ez9k.parta: [0.5069938581379673]
# kvig7fcCVc.partb: [0.6348214285714285]
# Ok-iIHxjgx.parta: [0.5989947552447552]
# hyei4uD81i.parta: [0.6240893590637836]
# Test AUC 2a: [0.5904904090885712]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6232460243217961
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6667436803479206
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.4802445074415308
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5227993269792452
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.44152065458829204
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5059485143750753
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.47645619554090823
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.38789062500000004
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.5822146603396603
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.44680500658761535
#
#
#
#
# Training AUC (similar to 1b): [0.564137174196225]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5357223562168988]
# Ok-iIHxjgx.partb: [0.6046490723428736]
# 1zsCldT4p8.set1: [0.5688743054439144]
# DebcfZEEmI.proper_fractions: [0.5264311060022989]
# 9wRCzK1G7F.partb: [0.45875313605691526]
# 1zsCldT4p8.set2: [0.504927139713317]
# nl-M69Ez9k.parta: [0.5593922790676437]
# kvig7fcCVc.partb: [0.5544032143962506]
# Ok-iIHxjgx.parta: [0.6065343208677351]
# hyei4uD81i.parta: [0.6842933130699088]
# Test AUC 1b: [0.5971483559773503]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.6238176904687662]
# Ok-iIHxjgx.partb: [0.664694889915738]
# 1zsCldT4p8.set1: [0.46199503897944716]
# DebcfZEEmI.proper_fractions: [0.5436340125117953]
# 9wRCzK1G7F.partb: [0.4240843641111892]
# 1zsCldT4p8.set2: [0.5227926139781066]
# nl-M69Ez9k.parta: [0.4975095498464534]
# kvig7fcCVc.partb: [0.6295758928571429]
# Ok-iIHxjgx.parta: [0.5985576923076923]
# hyei4uD81i.parta: [0.62017554057196]
# Test AUC 2a: [0.5894691293756049]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.6238176904687662
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6637979070399564
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.5364324946846208
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.521800779865296
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.4176122855946577
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5051575845061951
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.4650525553641425
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.3665178571428571
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.55071491008991
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.4602514919011082
#
#
#
#
# Model has converged!
# Training AUC (similar to 1b): [0.567356611614229]
# Training AUC (similar to 1a):
# p7cfRPp-kQ.partb: [0.5361044681546889]
# Ok-iIHxjgx.partb: [0.6059494702526488]
# 1zsCldT4p8.set1: [0.5690350687609194]
# DebcfZEEmI.proper_fractions: [0.5262956669498725]
# 9wRCzK1G7F.partb: [0.46041322832013704]
# 1zsCldT4p8.set2: [0.5049295188247189]
# nl-M69Ez9k.parta: [0.5563061890738077]
# kvig7fcCVc.partb: [0.552605617455896]
# Ok-iIHxjgx.parta: [0.604945766553343]
# hyei4uD81i.parta: [0.6841945288753799]
# Test AUC 1b: [0.6012793077274364]
# Test AUC 1a:
# p7cfRPp-kQ.partb: [0.624197718532377]
# Ok-iIHxjgx.partb: [0.667650856210927]
# 1zsCldT4p8.set1: [0.4626373139617293]
# DebcfZEEmI.proper_fractions: [0.5436265234084408]
# 9wRCzK1G7F.partb: [0.4234811550389247]
# 1zsCldT4p8.set2: [0.5229820762660893]
# nl-M69Ez9k.parta: [0.4944354979651961]
# kvig7fcCVc.partb: [0.6286830357142857]
# Ok-iIHxjgx.parta: [0.5949675324675325]
# hyei4uD81i.parta: [0.6184995737425405]
# Test AUC 2a: [0.5946702135452628]
# Test AUC 2b:
# Starting p7cfRPp-kQ.partb
# p7cfRPp-kQ.partb: 0.624197718532377
# Starting Ok-iIHxjgx.partb
# Ok-iIHxjgx.partb: 0.6611137537374285
# Starting 1zsCldT4p8.set1
# 1zsCldT4p8.set1: 0.5658442593905032
# Starting DebcfZEEmI.proper_fractions
# DebcfZEEmI.proper_fractions: 0.5076588563639903
# Starting 9wRCzK1G7F.partb
# 9wRCzK1G7F.partb: 0.5832534968384748
# Starting 1zsCldT4p8.set2
# 1zsCldT4p8.set2: 0.5249639119451461
# Starting nl-M69Ez9k.parta
# nl-M69Ez9k.parta: 0.45561193918058573
# Starting kvig7fcCVc.partb
# kvig7fcCVc.partb: 0.34715401785714284
# Starting Ok-iIHxjgx.parta
# Ok-iIHxjgx.parta: 0.47800636863136864
# Starting hyei4uD81i.parta
# hyei4uD81i.parta: 0.4823490661086569
